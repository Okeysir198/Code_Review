# %% [markdown]
# ## Call center Agent

# %% [markdown]
# https://github.com/langchain-ai/langchain-academy

# %% [markdown]
# ### Module Import and Auto-Reload

# %%
# Make sure autoreload is properly set up for auto reload the module if changes
# %load_ext autoreload
# %autoreload 2

# %%
import os, sys
from dotenv import load_dotenv, find_dotenv

current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)


_ = load_dotenv(find_dotenv())

# print(os.environ.get('OPENAI_API_KEY'))
print(parent_dir)
# Out:
# /home/ct-admin/Documents/Langgraph/00_AudioProject/02_Call_Center_AI_Agent

# %% [markdown]
# ### Phoenix for tracing LLM

# %%
# from phoenix.otel import register

# os.environ['PHOENIX_COLLECTOR_ENDPOINT'] = "http://localhost:6006"

# trace_provider =  register(
#     project_name="AgentWithToolsAndMemory",
#     auto_instrument=True

# )

# %% [markdown]
# <!-- Username
# Vehicle registration
# Vehicle Make
# Vehicle Model
# Vehicle colour
# Email address
# Full ID/Passport number (Can be confirmed on its own)
#
# --Date of birth
# --VIN Number
# --Residential Address
# --Contact Number -->

# %% [markdown]
# ### A. Connect to CAMS SQL database

# %%
from src.Database import CartrackSQLDatabase
import json
# user_id = '28173'
user_id = '70997'
user_id = "963262"
user_id = "28173"
user_id= '1035923'
user_id= '10003'
user_id ='1216242' # work for debtor letters
# user_id ='1911088'





#Step 2: get client info verification
# get_client_vehicle_info.invoke(user_id)
print(json.dumps(CartrackSQLDatabase.get_client_profile.invoke(user_id),indent=2))

# CartrackSQLDatabase.client_call_verification.invoke(user_id)


# #Step 3: reason for call
# CartrackSQLDatabase.get_client_account_aging.invoke(user_id)
# CartrackSQLDatabase.get_client_account_status.invoke(user_id)

# CartrackSQLDatabase.get_client_billing_analysis.invoke(user_id)

# #Step 4: Negotiation
# print(json.dumps(CartrackSQLDatabase.get_client_contracts.invoke(user_id),indent=2))

# CartrackSQLDatabase.get_client_account_overview.invoke(user_id)

# #Step 5: Promise to pay (PTP)
# CartrackSQLDatabase.get_client_account_statement.invoke(user_id)
# CartrackSQLDatabase.get_client_banking_details.invoke(user_id)
# CartrackSQLDatabase.get_client_payment_history.invoke(user_id)

# CartrackSQLDatabase.get_client_notes.invoke(user_id)
# CartrackSQLDatabase.get_client_debtor_letters.invoke(user_id)

# CartrackSQLDatabase.get_client_failed_payments.invoke(user_id)
# CartrackSQLDatabase.get_client_last_successful_payment.invoke(user_id)
# CartrackSQLDatabase.get_client_last_valid_payment.invoke(user_id)
# CartrackSQLDatabase.get_client_last_reversed_payment.invoke(user_id) # not work yet


# CartrackSQLDatabase.get_client_debit_mandates.invoke(user_id)
# CartrackSQLDatabase.update_payment_arrangements.invoke(user_id)

# CartrackSQLDatabase.get_payment_arrangement_types.invoke("")

# CartrackSQLDatabase.get_bank_options.invoke({'trigger':True})

# CartrackSQLDatabase.db.execute_query("select * from ct.individual where user_id ='1911088';")
# CartrackSQLDatabase.db.execute_query("select * from ct.individual_extra where individual_extra_id ='1911088';")
# Out:
# 2025-05-30 10:58:08,294 - INFO - PyTorch version 2.7.0+cu128 available.
# 2025-05-30 10:58:10,712 - INFO - Database connection established successfully
# {
#   "user_name": "MANI00347",
#   "client_info": {
#     "title": "Mrs",
#     "first_name": "Vasanthie",
#     "last_name": "Manikam",
#     "id_number": "1216242",
#     "passport": "",
#     "employer": "",
#     "client_full_name": "Vasanthie Manikam",
#     "date_of_birth": null,
#     "email_address": "dev@onecell.co.za",
#     "contact": {
#       "telephone": "000 000 0000",
#       "fax": "000 000 0000",
#       "mobile": "000 000 0000"
#     }
#   },
#   "addresses": [
#     {
#       "type": "Physical",
#       "address_line1": "FLAT 102 SOVEREIGN HOUSE",
#       "address_line2": "FELIX DLAMINI",
#       "post_code": "4091",
#       "province": "KwaZulu-Natal"
#     },
#     {
#       "type": "Postal",
#       "address_line1": "FLAT 102 SOVEREIGN HOUSE",
#       "address_line2": "FELIX DLAMINI",
#       "post_code": "4091",
#       "province": "KwaZulu-Natal"
#     }
#   ],
#   "vehicles": [
#     {
#       "registration": "JPX395MP",
#       "make": "Renault",
#       "model": "Kwid Expression 1 litre",
#       "color": "Charcoal",
#       "chassis_number": "MEEBBA00900608303",
#       "model_year": 2018,
#       "contract_status": "Active",
#       "terminal_serial": "RM119535",
#       "terminal_last_response": "2024-02-28T13:42:53.543158+02:00"
#     }
#   ],
#   "sim_card": {
#     "chip_id": "39828704"
#   },
#   "fitment": {
#     "date": "2021-01-25 12:47:04.118794+02",
#     "fitter_name": "Moeketsi"
#   },
#   "billing": {
#     "product_package": "Quick 2020",
#     "recovery_option": "true"
#   }
# }

# %%
from src.Database.CartrackSQLDatabase import *
user_id= '10003'
create_mandate.invoke({
    'user_id':user_id,
    'service':'service',
    'amount':100,
    'collection_date': '2025-05-21',
})
# Out:
# {'success': True,
#  'message': 'Once-off mandate created successfully',
#  'mandate_id': 2991303,
#  'mandate_type': 'Once-off',
#  'contract_count': 1}

# %%
from src.Database.CartrackSQLDatabase import *
user_id= '10003'
create_debicheck_payment.invoke({
    'user_id':user_id,
    'payment_amount':100,
    'payment_date': '2025-06-02',
    'note':"test_ai_agent"
})
# Out:
# {'success': True,
#  'message': 'Successfully created Once-off mandate and payment arrangement with 1 installment(s)',
#  'mandate_id': 2991307,
#  'arrangement_id': 381877404,
#  'mandate_type': 'Once-off'}

# %%
from src.Database.CartrackSQLDatabase import *
user_id= '10003'
create_payment_arrangement.invoke({
    'user_id':user_id,
    'pay_type_id':1,
    'payment1':100,
    'date1': '2025-06-05',
    'note':"test_ai_agent"
})
# Out:
# {'success': False,
#  'message': 'DebiCheck payments (pay_type_id=1) require a mandate_id1. Please create a mandate first using create_mandate().',
#  'arrangement_id': None}

# %%
from src.Database.CartrackSQLDatabase import *
print(user_id)
create_payment_arrangement_payment_portal.invoke({
    'user_id':user_id,
    'payment_type_id':2,
    'amount':100,
    'payment_date': '2025-06-06',
})
# Out:
# 10003
# {'success': True,
#  'message': 'Payment arrangement created successfully through payment portal',
#  'arrangement_id': 381877409,
#  'online_payment_reference_id': '6ccdd36b-31e5-4bdf-b54f-709cb8e677cb'}

# %%
from src.Database.CartrackSQLDatabase import *
generate_sms_payment_url.invoke({
    'user_id':user_id,
    'amount':100,
})
# Out:
# {'success': True,
#  'message': 'Payment URL generated successfully',
#  'payment_url': 'https://za.cartrack.com/pay/aa804276-3d33-44b4-90bb-01a6462587c5',
#  'reference_id': 'aa804276-3d33-44b4-90bb-01a6462587c5'}

# %%
from src.Database.CartrackSQLDatabase import *
user_id= '10003'
update_client_banking_details.invoke({
  "user_id": user_id,
  "update_fields": {
    "debit_run_day_id": 0
  },
  
  
})

# %%
from src.Database.CartrackSQLDatabase import *
user_id= '10003'
update_client_contact_number.invoke({
  "user_id": user_id,
  "mobile_number": '0988799845',
})
# Out:
# {'success': True,
#  'message': 'Mobile number updated successfully',
#  'previous_number': '0988799845',
#  'current_number': '0988799845'}

# %%
from src.Database.CartrackSQLDatabase import *
user_id= '10003'
update_client_email.invoke({
  "user_id": user_id,
  "email_address": 'ai_agent@ai_agent.com',
})
# Out:
# {'success': True,
#  'message': 'Email address updated successfully',
#  'previous_email': 'ai_agent@ai_agent.com',
#  'current_email': 'ai_agent@ai_agent.com'}

# %%
from src.Database.CartrackSQLDatabase import *
user_id = '28173'
add_client_note.invoke({
    'user_id':user_id,
    'note_text':"ai_agent add note test",
})
# Out:
# 2025-05-21 17:12:38,755 - INFO - Adding note for client 28173 at 2025-05-21 17:12:38
# {'success': True,
#  'message': 'Note added successfully at 2025-05-21 17:12:38',
#  'client_note_id': 265999222}

# %% [markdown]
# ### Data builder for prompt

# %%
from src.Agents.call_center_agent.data_parameter_builder import (
    get_client_data,
    prepare_parameters
)
# client_data = preload_call_data(user_id="83906", agent_name="John Smith")
client_data = get_client_data(user_id="83906", force_reload=True)
# client_data
# Out:
# 2025-05-27 22:58:41,724 - INFO - Fetching fresh data for user_id: 83906
# 2025-05-27 22:58:57,948 - INFO - Successfully loaded data for user_id: 83906

# %%
from src.Agents.call_center_agent.data_parameter_builder import (
    get_client_data_async,
    prepare_parameters
)
client_data = await get_client_data_async(user_id="83905", force_reload=True)

client_data
# Out:
# 2025-05-27 22:59:26,077 - INFO - Fetching fresh data asynchronously for user_id: 83905
# 2025-05-27 22:59:26,078 - INFO - Executing 11 concurrent database calls for user_id: 83905
# 2025-05-27 22:59:36,093 - INFO - Completed concurrent database calls in 10.01 seconds
# 2025-05-27 22:59:36,095 - INFO - Successfully loaded async data for user_id: 83905 in 10.01s
# {'user_id': '83905',
#  'profile': {'user_name': 'TONG00010',
#   'client_info': {'title': 'Mr',
#    'first_name': 'Teko',
#    'last_name': 'Tongwane',
#    'id_number': '83905',
#    'passport': '',
#    'employer': '',
#    'client_full_name': 'Teko Tongwane',
#    'date_of_birth': None,
#    'email_address': 'dev@onecell.co.za',
#    'contact': {'telephone': '000 000 0000',
#     'fax': '000 000 0000',
#     'mobile': '000 000 0000'}},
#   'addresses': [{'type': 'Physical',
#     'address_line1': 'House No 1379',
#     'address_line2': 'Unit 2',
#     'post_code': '8474',
#     'province': 'NC'},
#    {'type': 'Postal',
#     'address_line1': 'P.O Box 3143',
#     'address_line2': '',
#     'post_code': '8447',
#     'province': 'NC'}],
#   'vehicles': [{'registration': 'TEMP-CT723744',
#     'make': 'Toyota',
#     'model': 'Hilux 2.7i D/C',
#     'color': 'White',
#     'chassis_number': 'AHT33UNK408013741',
#     'model_year': 2002,
#     'contract_status': 'Cancelled',
#     'terminal_serial': None,
#     'terminal_last_response': None}],
#   'sim_card': {'chip_id': ''},
#   'fitment': {'date': '', 'fitter_name': ''},
#   'billing': {'product_package': '', 'recovery_option': ''}},
#  'account_overview': {'user_id': '83905',
#   'user_name': 'TONG00010',
#   'client': 'Teko Tongwane',
#   'client_type': 'Individual',
#   'intro_date': '2007-12-13',
#   'last_successful_payment_date': '2012-11-01',
#   'percentage_total_billing': '94.30',
#   'total_invoices': '7001.5200',
#   'total_paid': '6602.5200',
#   'monthly_debit_order_total': '0.00',
#   'vehicle_count_total': '1',
#   'vehicle_count_active': '0',
#   'payment_status': 'Dispute',
#   'run_status': 'Dispute',
#   'naedo_tracking': 'No',
#   'naedo_special': 'No',
#   'sale_agent': 'Cartrack Northern Cape Reception',
#   'account_status': 'Cancelled - Good Standing',
#   'payment_arrangement': 'No',
#   'debit_order_date': 'Last Day/Month',
#   'debit_order_logic': 'Client',
#   'service_status': 'Soft Lock',
#   'rating': '5',
#   'last_agent_contact_date': '',
#   'last_agent_contact': '',
#   'department': 'Debtors-Monthly Debit order total < R400-del-del',
#   'responsible_agent': 'Irene Hlongo',
#   'cancellation_fee_charged': 'No',
#   'letter_of_demand_history': '',
#   'contactable': 'Yes',
#   'contact_details_valid': '',
#   'bank_updated': 'No',
#   'bank_invalid': 'Invalid',
#   'allow_debit_order': 'Yes',
#   'subscription': '0',
#   'next_invoice_date': '',
#   'last_invoice_date': '',
#   'technical_issue': 'No',
#   'disputes': 'No',
#   'cancellation_fee': '0',
#   'invoice_not_raised': '0',
#   'invoice_not_raised_from': '',
#   'disputes_historic': 'Yes',
#   'suspend_billing': 'No',
#   'blacklisted': 'No',
#   'blacklisted_date': '',
#   'lastdisposition': '',
#   'mandate': 'N/A',
#   'rating_colour': 'Platinum',
#   'special_instruction': '',
#   'tax_reg_number': '',
#   'employer': '',
#   'collection_instruction': ''},
#  'account_aging': {'x0': '0.0000',
#   'x30': '0.0000',
#   'x60': '0.0000',
#   'x90': '0.0000',
#   'x120': '0.0000',
#   'xbalance': '0.0000'},
#  'banking_details': {'user_bank_account_id': 29876874,
#   'user_id': 83905,
#   'bank_account_type_id': 2,
#   'account_name': 'Tongwane T',
#   'branch_code': '001255',
#   'account_number': 'anonymized-684863',
#   'bank_id': 27,
#   'auth': '',
#   'branch_name': 'Kathu',
#   'invoice_option_id': 1,
#   'isactive': 1,
#   'credit_card_type_id': 0,
#   'credit_card_number': '',
#   'exp_date': '',
#   'cdv': None,
#   'debit_run_day_id': 2,
#   'rejected': 1,
#   'debit_on_salary_date': None,
#   'salary_day': None,
#   'new_debit_run_day_id': None,
#   'new_salary_day': None,
#   'new_debit_on_salary_date': None,
#   'new_invoice_option_id': None,
#   'separate_billing_run': 0,
#   'rejected_reason': 'unknown',
#   'pre_legal': None,
#   'credit_card_token': None,
#   'pacs_service_id': 2,
#   'suspend_billing': False,
#   'first_name': None,
#   'last_name': None,
#   'id_number': '4838931726741',
#   'passport_number': None,
#   'mandate': None,
#   'non_primary_account': False,
#   'bank_account_category_id': 0,
#   'mandate_client': None,
#   'debit_order_bank_id': 13,
#   'invoice_option_subtype_id': None,
#   'bank_name': 'STANDARD BANK OF S. A.',
#   'disabled': False,
#   'avs': True,
#   'allow_debit': True,
#   'allow_mandate': True,
#   'allow_debit_savings_account': True,
#   'bank_account_type': 'Cheque',
#   'bank_account_category': 'Unknown',
#   'invoice_option': 'Direct Debit',
#   'debit_run_day': 28,
#   'debit_run_day_display_name': 'Last Day/Month',
#   'pacs_service': 'Two day',
#   'payment_method': 'Direct Debit',
#   'debit_date': 'Last Day/Month',
#   'account_bank': 'STANDARD BANK OF S. A.',
#   'account_branch_code': '001255',
#   'account_state': 'Good',
#   'credit_controller': 'Irene Hlongo',
#   'payment_terms': '0',
#   'account_branch_name': 'Kathu',
#   'client_classification': '',
#   'account_rejected': 'Rejected',
#   'account_category': 'Unknown',
#   'non_primary': 'Primary'},
#  'subscription': {'subscription_amount': 'None',
#   'calculation_period': 'Current active contracts only'},
#  'payment_history': [],
#  'failed_payments': [{'payment_date': '2012-09-12',
#    'failure_reason': 'Unpaid - 30'},
#   {'payment_date': '2011-02-02', 'failure_reason': 'Unpaid - 4'}],
#  'last_successful_payment': {'payment_id': '8365416',
#   'payment_date': '2012-11-01',
#   'payment_amount': '118.58'},
#  'contracts': [{'contract_id': 29876893,
#    'product_package_id': 1,
#    'payment_option_id': 1,
#    'deal_category_id': 8,
#    'sale_date': '2007-12-13T09:48:23.347647+02:00',
#    'contract_start_date': '2007-12-13T09:52:04.374925+02:00',
#    'contract_end_date': '2012-10-23T07:37:04.694926+02:00',
#    'contract_package_id': 43211116,
#    'client_id': 83905,
#    'vehicle_id': 29876891,
#    'terminal_id': 29689322,
#    'fitment_agent_id': 29818,
#    'sale_agent_id': 29820,
#    'contract_period': None,
#    'billing_client_id': 83905,
#    'fitment_date': '2007-12-13T09:52:04.374925+02:00',
#    'fitment_booking_date': None,
#    'contract_state_id': 4,
#    'fitter_id': 29872,
#    'qa_id': None,
#    'terminal_grid_location': 'rd',
#    'fitment_audit_number': 'D000-1676C1',
#    'branch_id': 5193336,
#    'parent_contract_id': None,
#    'fc_reference': '',
#    'commission_sale_agent_id': 29820,
#    'account_manager_id': 29820,
#    'certificate_no': None,
#    'royalty_amt': '20.00',
#    'cancelation_reason_id': 25,
#    'papers_rec': 1,
#    'fitment_priority': 3,
#    'logger': 'VENT00041',
#    'hw_pay_method': None,
#    'combo_terminal_id': None,
#    'pending_text': None,
#    'cancelation_text': 'Cancel Request removed by Contract Cancelation - Removed',
#    'qa_recoverability': None,
#    'qa_fitment_quality': None,
#    'potential_id': None,
#    'recovery_warranty_id': None,
#    'anniversary_date': None,
#    'dealership_id': None,
#    'payment_option': 'Cash Sale',
#    'deal_category': 'Agents',
#    'contract_state': 'Cancelled',
#    'cancelation_reason_text': 'No longer an Insurance Requirement'}],
#  'billing_analysis': {'user_id': 83905,
#   'updated_ts': '2025-03-05T11:25:09.611703+02:00',
#   'created_ts': '2012-09-14T04:00:01.379694+02:00',
#   'balance_total': '0.00',
#   'balance_current': '0.00',
#   'balance_30_days': '0.00',
#   'balance_60_days': '0.00',
#   'balance_90_days': '0.00',
#   'balance_120_days': '0.00',
#   'error': '0.00',
#   'last_kam': 'Cartrack Northern Cape Reception',
#   'branch_name': 'Northern Cape',
#   'source': 'Cartrack Northern Cape Reception',
#   'insurance_broker': None,
#   'username': 'TONG00010',
#   'full_name': 'Teko Tongwane',
#   'invoice_option': 'Direct Debit',
#   'client_type': 'Individual',
#   'credit_controller': 'Irene Hlongo',
#   'crv': '119.63',
#   'last_letter': None,
#   'last_letter_date': None,
#   'price_table': 'Table 1-Standard Prices(Old)',
#   'payment_arrangement': 'No',
#   'pre_legal_billing': 'No',
#   'age_days': None,
#   'rejected': 'Yes',
#   'rejected_reason': 'unknown',
#   'first_contract_start_date': '2007-12-13',
#   'industry_sector': None,
#   'ratio': '0.00',
#   'annual_recurring_revenue_excl_vat': None,
#   'vehicle_count': 0,
#   'unbilled_subscription': None,
#   'day_120': '0.00',
#   'day_150': '0.00',
#   'day_180': '0.00',
#   'day_210': '0.00',
#   'day_240': '0.00',
#   'day_270': '0.00',
#   'day_300': '0.00',
#   'day_330': '0.00',
#   'day_360': '0.00',
#   'day_390': '0.00',
#   'day_420': '0.00',
#   'day_450': '0.00'},
#  'existing_mandates': [],
#  'loaded_at': datetime.datetime(2025, 5, 27, 22, 59, 36, 95019),
#  'load_duration_seconds': 10.014997}

# %%
from src.Database import CartrackSQLDatabase

CartrackSQLDatabase.get_client_account_overview.invoke({"user_id":"83906"})
# Out:
# {'user_id': '83906',
#  'user_name': 'OELO00016',
#  'client': 'Linda Oelofse',
#  'client_type': 'Individual',
#  'intro_date': '2004-12-30',
#  'last_successful_payment_date': '2025-04-24',
#  'percentage_total_billing': '28.04',
#  'total_invoices': '5670.0000',
#  'total_paid': '1590.0000',
#  'monthly_debit_order_total': '10535.69',
#  'vehicle_count_total': '61',
#  'vehicle_count_active': '59',
#  'payment_status': '',
#  'run_status': 'Dated',
#  'naedo_tracking': 'No',
#  'naedo_special': 'No',
#  'sale_agent': 'East Rand Toyota',
#  'account_status': 'Active',
#  'payment_arrangement': 'Broken Promise',
#  'debit_order_date': '1st',
#  'debit_order_logic': 'Client',
#  'service_status': 'Active',
#  'rating': '5',
#  'last_agent_contact_date': '',
#  'last_agent_contact': '',
#  'department': 'Terminated',
#  'responsible_agent': 'Karabo Dire',
#  'cancellation_fee_charged': 'No',
#  'letter_of_demand_history': '',
#  'contactable': 'Yes',
#  'contact_details_valid': 'Valid Contact Details',
#  'bank_updated': 'Yes',
#  'bank_invalid': 'Valid',
#  'allow_debit_order': 'Yes',
#  'subscription': '10535.6900',
#  'next_invoice_date': '2025-06-01',
#  'last_invoice_date': '2025-04-01',
#  'technical_issue': 'Yes',
#  'disputes': 'No',
#  'cancellation_fee': '27325.2300',
#  'invoice_not_raised': '0',
#  'invoice_not_raised_from': '',
#  'disputes_historic': 'No',
#  'suspend_billing': 'No',
#  'blacklisted': 'No',
#  'blacklisted_date': '',
#  'lastdisposition': '2025/04/02 18:18: Call back',
#  'mandate': 'N/A',
#  'rating_colour': 'Platinum',
#  'special_instruction': '',
#  'tax_reg_number': '',
#  'employer': 'Self-Employed',
#  'collection_instruction': ''}

# %%
client_data.get("profile")["client_info"]["client_full_name"] 
client_data.get("profile")
# Out:
# {'user_name': 'OELO00016',
#  'client_info': {'title': 'Mrs',
#   'first_name': 'Linda',
#   'last_name': 'Oelofse',
#   'id_number': '83906',
#   'passport': '',
#   'employer': '',
#   'client_full_name': 'Linda Oelofse',
#   'date_of_birth': None,
#   'email_address': 'dev@onecell.co.za',
#   'contact': {'telephone': '123456789',
#    'fax': '987654321000',
#    'mobile': '111222333'}},
#  'addresses': [{'type': 'Physical',
#    'address_line1': 'P O BOX 15076',
#    'address_line2': 'Lambton',
#    'post_code': '1414',
#    'province': 'Gauteng'},
#   {'type': 'Postal',
#    'address_line1': 'P O BOX 15076',
#    'address_line2': 'Lambton',
#    'post_code': '1414',
#    'province': 'Gauteng'}],
#  'vehicles': [{'registration': 'JY96NMGP',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTJB3DD3045226941MN',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'BA002202',
#    'terminal_last_response': '2021-12-08T20:55:55.385332+02:00'},
#   {'registration': 'TEMP-11328241MN',
#    'make': 'Toyota',
#    'model': 'Fortuner',
#    'color': 'Blue',
#    'chassis_number': 'AHTCB3GS2020159941MN',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'BA017926',
#    'terminal_last_response': '2021-12-09T13:28:39.584658+02:00'},
#   {'registration': 'TEMP-1164363TT',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'AHTSS22P707129579',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF089306',
#    'terminal_last_response': '2022-03-13T00:51:43.080275+02:00'},
#   {'registration': '52VIV021811MN',
#    'make': 'Volkswagen',
#    'model': 'Polo(5DR)',
#    'color': 'Blue',
#    'chassis_number': 'AAVZZZ6RZMU0193671MN',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'BS162550',
#    'terminal_last_response': '2022-03-27T22:25:46.102889+02:00'},
#   {'registration': 'YNS744GPCTGW',
#    'make': 'Land Rover',
#    'model': 'Defender 90',
#    'color': 'Light Yellow',
#    'chassis_number': 'SALLDVB775V058268',
#    'model_year': 2005,
#    'contract_status': 'Active',
#    'terminal_serial': 'CW075339',
#    'terminal_last_response': '2022-06-17T08:16:08.888208+02:00'},
#   {'registration': 'KJK141NW',
#    'make': 'Nissan',
#    'model': 'NP200',
#    'color': 'White',
#    'chassis_number': 'ADNUSN1D5U0112492',
#    'model_year': 2016,
#    'contract_status': 'Active',
#    'terminal_serial': 'CY131636',
#    'terminal_last_response': '2023-02-16T08:45:42.579579+02:00'},
#   {'registration': 'LB31HFGPQ',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTBA3CD206245243Q',
#    'model_year': 2023,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF319856',
#    'terminal_last_response': '2023-03-11T13:37:26.268461+02:00'},
#   {'registration': 'FWD662MPNEW',
#    'make': 'Volkswagen',
#    'model': 'Golf 6 1.4 TSI Highline',
#    'color': 'Blue',
#    'chassis_number': 'WVWZZZ1KZCW342618',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'BS112324',
#    'terminal_last_response': '2023-03-28T10:28:57.570416+02:00'},
#   {'registration': 'KJK141NWSEC',
#    'make': 'Nissan',
#    'model': 'NP200',
#    'color': 'White',
#    'chassis_number': 'ADNUSN1D5U0112492',
#    'model_year': 2016,
#    'contract_status': 'Active',
#    'terminal_serial': 'RN033381',
#    'terminal_last_response': '2023-03-30T14:39:40.329568+02:00'},
#   {'registration': 'TEMP-1116910',
#    'make': 'Volkswagen',
#    'model': 'Polo(5DR)',
#    'color': 'Blue',
#    'chassis_number': 'AAVZZZ6RZMU019367',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'BS176260',
#    'terminal_last_response': '2023-05-12T07:23:14.030245+02:00'},
#   {'registration': 'FHK284MP',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AMTCR32G208011150',
#    'model_year': 2010,
#    'contract_status': 'Active',
#    'terminal_serial': 'CX1069261',
#    'terminal_last_response': '2023-05-25T09:37:54.736155+02:00'},
#   {'registration': 'YJB747GP',
#    'make': 'Ford',
#    'model': 'FORTUNER 3.0 4D',
#    'color': 'White',
#    'chassis_number': 'AHTZZ69G305010298',
#    'model_year': 2009,
#    'contract_status': 'Active',
#    'terminal_serial': 'CX1037401',
#    'terminal_last_response': '2023-06-15T10:40:25.422974+02:00'},
#   {'registration': 'JRP184MP',
#    'make': 'Audi',
#    'model': 'A5',
#    'color': 'White',
#    'chassis_number': 'WAUZZZ8T1DA018469',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF299407',
#    'terminal_last_response': '2023-06-16T07:18:13.422302+02:00'},
#   {'registration': 'BG02LBGPNEW',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'JTFSX22PX06105921',
#    'model_year': 2011,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF166160',
#    'terminal_last_response': '2023-06-16T16:35:03.464851+02:00'},
#   {'registration': 'XHD206GPNEW',
#    'make': 'Toyota',
#    'model': 'Tazz',
#    'color': 'Gold',
#    'chassis_number': 'AHT54EE900A031885',
#    'model_year': 2005,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF375248',
#    'terminal_last_response': '2023-06-16T20:18:45.993275+02:00'},
#   {'registration': 'TEMP-13870421MN',
#    'make': 'Ford',
#    'model': 'Ranger',
#    'color': 'White',
#    'chassis_number': 'AFANXXMJ2NJL49773',
#    'model_year': 2018,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF395313',
#    'terminal_last_response': '2023-06-16T20:34:23.872284+02:00'},
#   {'registration': '70DEM16504S2',
#    'make': 'Toyota',
#    'model': 'Fortuner',
#    'color': 'Silver',
#    'chassis_number': 'AHTJA3GS900244632S2',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF444297',
#    'terminal_last_response': '2023-06-16T22:31:40.671608+02:00'},
#   {'registration': 'TEMP-1378619',
#    'make': 'Toyota',
#    'model': 'Fortuner',
#    'color': 'Silver',
#    'chassis_number': 'AHTJA3GS900244632',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF445089',
#    'terminal_last_response': '2023-06-16T22:40:14.631297+02:00'},
#   {'registration': 'KT89RTGP',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTAA3DC201712112',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE012957',
#    'terminal_last_response': '2023-06-17T07:39:31.640903+02:00'},
#   {'registration': 'TEMP-1164363',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'AHTSS22P707129579',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'RS080556',
#    'terminal_last_response': '2023-06-19T11:47:05.729689+02:00'},
#   {'registration': 'BG02LBGP',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'JTFSX22PX06105921',
#    'model_year': 2011,
#    'contract_status': 'Active',
#    'terminal_serial': 'CA021973',
#    'terminal_last_response': '2023-06-30T17:23:46.188902+02:00'},
#   {'registration': 'YJB747GPSEC',
#    'make': 'Toyota',
#    'model': 'Fortuner',
#    'color': 'White',
#    'chassis_number': 'AHTZZ69G305010298',
#    'model_year': 2009,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF428853',
#    'terminal_last_response': '2023-08-12T14:10:50.986926+02:00'},
#   {'registration': 'XHD206GPOLD',
#    'make': 'Toyota',
#    'model': 'Tazz',
#    'color': 'Gold',
#    'chassis_number': 'AHT54EE900A031885OLD',
#    'model_year': 2005,
#    'contract_status': 'Active',
#    'terminal_serial': 'CT709161',
#    'terminal_last_response': '2023-08-18T05:23:02.297593+02:00'},
#   {'registration': 'HJ35WGGP',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'AHTSS22P107040137',
#    'model_year': 2018,
#    'contract_status': 'Active',
#    'terminal_serial': 'RQ020860',
#    'terminal_last_response': '2023-08-20T13:31:05.977692+02:00'},
#   {'registration': 'YNS744GPCT5',
#    'make': 'Land Rover',
#    'model': 'Defender 90',
#    'color': 'Light Yellow',
#    'chassis_number': 'SALLDVB775V058268',
#    'model_year': 2005,
#    'contract_status': 'Active',
#    'terminal_serial': 'CB000515',
#    'terminal_last_response': '2023-09-08T13:58:20.710530+02:00'},
#   {'registration': 'KT89RTGPSEC',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTAA3DC201712112',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE021268',
#    'terminal_last_response': '2023-09-18T09:37:08.858756+02:00'},
#   {'registration': 'TEMP-CA109657',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'AHTSX22P507004338',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'CA109657',
#    'terminal_last_response': '2023-10-28T17:03:57.793218+02:00'},
#   {'registration': 'HJ35WGGPTT',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'AHTSS22P107040137',
#    'model_year': 2018,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF280245',
#    'terminal_last_response': '2023-11-15T14:32:33.633300+02:00'},
#   {'registration': 'HJW137NW',
#    'make': 'Jeep',
#    'model': 'Cherokee',
#    'color': 'White',
#    'chassis_number': '1J8G458539W554331',
#    'model_year': 2020,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF339828',
#    'terminal_last_response': '2023-11-16T13:11:56.477268+02:00'},
#   {'registration': 'HX68RWGPCT9',
#    'make': 'Isuzu',
#    'model': 'FTR850',
#    'color': 'White',
#    'chassis_number': 'ACVFTR34H8N026064',
#    'model_year': 2019,
#    'contract_status': 'Active',
#    'terminal_serial': 'RQ030010',
#    'terminal_last_response': '2023-11-29T05:11:19.153451+02:00'},
#   {'registration': 'CF170860',
#    'make': 'Ford',
#    'model': 'Ranger',
#    'color': 'White',
#    'chassis_number': 'AFANXXMJ2NJL49773',
#    'model_year': 2018,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF437605',
#    'terminal_last_response': '2023-12-14T12:02:25.522682+02:00'},
#   {'registration': '68DEM817831MN',
#    'make': 'Volkswagen',
#    'model': 'Polo(5DR)',
#    'color': 'White',
#    'chassis_number': 'AAVZZZ6RZNU0104071MN',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF193643',
#    'terminal_last_response': '2023-12-20T06:57:29.745000+02:00'},
#   {'registration': 'JYW075EC',
#    'make': 'Volkswagen',
#    'model': 'Polo(5DR)',
#    'color': 'White',
#    'chassis_number': 'AAVZZZ6RZNU010407',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF192132',
#    'terminal_last_response': '2023-12-20T06:57:30.393830+02:00'},
#   {'registration': 'BX07CGGP',
#    'make': 'Ford',
#    'model': 'Ranger',
#    'color': 'White',
#    'chassis_number': 'AFANXXMJ2NCA35785B',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'CA090201',
#    'terminal_last_response': '2024-01-02T14:57:42.276948+02:00'},
#   {'registration': 'NUR25741FML',
#    'make': 'Nissan',
#    'model': 'NP200',
#    'color': 'White',
#    'chassis_number': 'ADNUSN1D5U0043647',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'CW067782',
#    'terminal_last_response': '2024-01-02T22:24:20.884928+02:00'},
#   {'registration': 'BL20JCGPSEC',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTEZ39G107023472',
#    'model_year': 2011,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE056321',
#    'terminal_last_response': '2024-01-03T13:53:09.345910+02:00'},
#   {'registration': 'XFY519GP',
#    'make': 'Isuzu',
#    'model': 'FTR 800',
#    'color': 'TBA',
#    'chassis_number': 'ADMFTR33M6Z444187',
#    'model_year': 2008,
#    'contract_status': 'Active',
#    'terminal_serial': 'CW055354',
#    'terminal_last_response': '2024-01-04T07:12:50.614813+02:00'},
#   {'registration': 'BW05HYGPSEC',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTCR32G508016973',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE162539',
#    'terminal_last_response': '2024-01-05T16:29:27.439879+02:00'},
#   {'registration': 'NUR25741',
#    'make': 'Nissan',
#    'model': 'NP200',
#    'color': 'White',
#    'chassis_number': 'ADNUSN1D5U0043647',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'CT826092',
#    'terminal_last_response': '2024-01-11T22:38:54.974052+02:00'},
#   {'registration': '76UFP81994S1',
#    'make': 'Volkswagen',
#    'model': 'Golf',
#    'color': 'Red',
#    'chassis_number': 'WVWZZZAUZHW317638S1',
#    'model_year': 2018,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE019999',
#    'terminal_last_response': '2024-01-13T13:02:42.487742+02:00'},
#   {'registration': 'KB06KGGP',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'Silver',
#    'chassis_number': 'AHTAA3DD001728205',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE162552',
#    'terminal_last_response': '2024-01-16T09:55:38.203816+02:00'},
#   {'registration': 'KB06KGGPSEC',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'Silver',
#    'chassis_number': 'AHTAA3DD001728205',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE164373',
#    'terminal_last_response': '2024-01-16T09:55:38.917089+02:00'},
#   {'registration': '12DEM498777S2-THINUS',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White, metallic',
#    'chassis_number': 'AHTJB3DC704498777S2',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'BH154835',
#    'terminal_last_response': '2024-01-29T12:09:58.393445+02:00'},
#   {'registration': '70HIL538096',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTBA3CC206538096',
#    'model_year': 2023,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE275992',
#    'terminal_last_response': '2024-02-02T07:12:08.633020+02:00'},
#   {'registration': '70HIL538096S2',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTBA3CC206538096S2',
#    'model_year': 2023,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE275970',
#    'terminal_last_response': '2024-02-02T07:12:38.907184+02:00'},
#   {'registration': 'TEMP-1524073',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTCW8CB101963509',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'BH070820',
#    'terminal_last_response': '2024-02-06T12:04:22.887409+02:00'},
#   {'registration': '25UFC59225S2',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'ANTCW8CB101963509S2',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'BH070751',
#    'terminal_last_response': '2024-02-06T12:04:41.352978+02:00'},
#   {'registration': 'HTS377FS',
#    'make': 'Ford',
#    'model': 'Figo',
#    'color': 'Grey',
#    'chassis_number': 'MAJGXXMTKGHC70747',
#    'model_year': 2017,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE082338',
#    'terminal_last_response': '2024-02-09T14:29:14.752694+02:00'},
#   {'registration': '12DEM498777-THINUS',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White, metallic',
#    'chassis_number': 'AHTJB3DC704498777',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'BH146747',
#    'terminal_last_response': '2024-02-09T14:45:24.491106+02:00'},
#   {'registration': 'ND12789',
#    'make': 'Audi',
#    'model': 'A5',
#    'color': 'White',
#    'chassis_number': 'WAUZZZ8T1DA018469.',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'CA105514',
#    'terminal_last_response': '2024-02-09T17:12:05.472180+02:00'},
#   {'registration': 'FIKA01GP',
#    'make': 'Toyota',
#    'model': 'Fortuner',
#    'color': 'Blue',
#    'chassis_number': 'AHTCB3GS202015994',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'EE263392',
#    'terminal_last_response': '2024-02-15T19:09:08.446293+02:00'},
#   {'registration': 'NUF7083',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'AHTSX22P507004338',
#    'model_year': 2017,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE050150',
#    'terminal_last_response': '2024-02-21T08:41:01.940466+02:00'},
#   {'registration': 'JY96NMGPNEW',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTJB3DD304522694',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'RM137684',
#    'terminal_last_response': '2024-02-21T16:07:48.904421+02:00'},
#   {'registration': 'BW48YHGPCT5',
#    'make': 'Isuzu',
#    'model': 'KB300 LE',
#    'color': 'WHITE',
#    'chassis_number': 'ADM2RD85CA4593760',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'CB000045',
#    'terminal_last_response': '2024-02-21T18:37:39.310320+02:00'},
#   {'registration': 'XFY519GPG1C',
#    'make': 'Isuzu',
#    'model': 'FTR800',
#    'color': 'White',
#    'chassis_number': 'ADMFTR33M6Z444187G1C',
#    'model_year': 2000,
#    'contract_status': 'Active',
#    'terminal_serial': 'GS128108',
#    'terminal_last_response': '2024-02-22T13:45:44.522558+02:00'},
#   {'registration': 'KMM209MP-MARYNABU',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTBA3CD006222950BU',
#    'model_year': 2023,
#    'contract_status': 'Active',
#    'terminal_serial': 'BH149135',
#    'terminal_last_response': '2024-02-27T14:00:31.058760+02:00'},
#   {'registration': 'STK5712',
#    'make': 'Ford',
#    'model': 'Ranger',
#    'color': 'White',
#    'chassis_number': 'AFAPXXMJ2PJP18921new',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'BH092493',
#    'terminal_last_response': '2024-02-29T11:33:36.182323+02:00'},
#   {'registration': 'STK57121MN',
#    'make': 'Ford',
#    'model': 'Ranger',
#    'color': 'White',
#    'chassis_number': 'AFAPXXMJ2PJP18921new1MN',
#    'model_year': 2018,
#    'contract_status': 'Active',
#    'terminal_serial': 'BH096332',
#    'terminal_last_response': '2024-02-29T11:34:27.166316+02:00'},
#   {'registration': 'TEMP-1538558',
#    'make': 'Volkswagen',
#    'model': 'Polo Vivo',
#    'color': 'Blue',
#    'chassis_number': 'AAVZZZ6R9RU008567',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'BH091312',
#    'terminal_last_response': '2024-03-01T14:36:26.016303+02:00'},
#   {'registration': '78VIV12716S1',
#    'make': 'Volkswagen',
#    'model': 'Polo Vivo',
#    'color': 'Blue',
#    'chassis_number': 'AAVZZZ6R9RU008567S1',
#    'model_year': 2023,
#    'contract_status': 'Active',
#    'terminal_serial': 'BH091343',
#    'terminal_last_response': '2024-03-01T14:36:56.409789+02:00'},
#   {'registration': 'XGY717GPCT9',
#    'make': 'Isuzu',
#    'model': 'FTR800',
#    'color': 'White',
#    'chassis_number': 'ADMFTR33M6Z430321',
#    'model_year': 2007,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF400206',
#    'terminal_last_response': '2024-03-05T09:29:32.837696+02:00'},
#   {'registration': 'XGY717GPFML',
#    'make': 'Isuzu',
#    'model': 'FTR800',
#    'color': 'White',
#    'chassis_number': 'ADMFTR33M6Z430321FML',
#    'model_year': 2007,
#    'contract_status': 'Active',
#    'terminal_serial': 'CW056222',
#    'terminal_last_response': '2024-03-05T09:31:17.257003+02:00'},
#   {'registration': 'RJG359GP',
#    'make': 'Isuzu',
#    'model': 'D-Max',
#    'color': 'White',
#    'chassis_number': 'ADMTFR54H4A203751',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'RE051775',
#    'terminal_last_response': '2024-03-09T09:24:39.259503+02:00'},
#   {'registration': 'XFY519GPQ',
#    'make': 'Isuzu',
#    'model': 'FTR800',
#    'color': 'White',
#    'chassis_number': 'ADMFTR33M6Z444187Q',
#    'model_year': 2000,
#    'contract_status': 'Active',
#    'terminal_serial': 'CY225198',
#    'terminal_last_response': '2024-03-11T08:20:42.371178+02:00'},
#   {'registration': 'FORD5319GREY',
#    'make': 'Ford',
#    'model': 'Ranger',
#    'color': 'Grey',
#    'chassis_number': 'AFAGXXMJ2GGG65319',
#    'model_year': 2018,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF078250',
#    'terminal_last_response': '2024-03-11T11:42:07.567557+02:00'},
#   {'registration': 'FORD5319GREY1MND',
#    'make': 'Ford',
#    'model': 'Ranger',
#    'color': 'Grey',
#    'chassis_number': 'AFAGXXMJ2GGG65319',
#    'model_year': 2018,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF082784',
#    'terminal_last_response': '2024-03-11T12:13:28.901872+02:00'},
#   {'registration': 'NV40342SEC',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'Blue',
#    'chassis_number': 'AHT31UNK408019822',
#    'model_year': 2003,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE141025',
#    'terminal_last_response': '2024-03-11T12:49:49.078778+02:00'},
#   {'registration': 'NV40342',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'Blue',
#    'chassis_number': 'AHT31UNK408019822',
#    'model_year': 2003,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE010941',
#    'terminal_last_response': '2024-03-11T13:13:37.922128+02:00'},
#   {'registration': '71VIV111651MN',
#    'make': 'Volkswagen',
#    'model': 'Polo(5DR)',
#    'color': 'White',
#    'chassis_number': 'AAVZZZ6RZNU0120981MN',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF209952',
#    'terminal_last_response': '2024-03-11T14:32:52.204082+02:00'},
#   {'registration': 'JYT587EC',
#    'make': 'Volkswagen',
#    'model': 'Polo(5DR)',
#    'color': 'White',
#    'chassis_number': 'AAVZZZ6RZNU012098',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF210046',
#    'terminal_last_response': '2024-03-11T14:33:45.633772+02:00'},
#   {'registration': 'CC53KMGPQ',
#    'make': 'Nissan',
#    'model': 'UD40',
#    'color': 'White',
#    'chassis_number': 'ADDM03000000050955Q',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'CY500625',
#    'terminal_last_response': '2024-03-18T05:43:07.044881+02:00'},
#   {'registration': 'XGY717GPQ',
#    'make': 'Isuzu',
#    'model': 'FTR800',
#    'color': 'White',
#    'chassis_number': 'ADMFTR33M6Z430321',
#    'model_year': 2007,
#    'contract_status': 'Active',
#    'terminal_serial': 'CY464755',
#    'terminal_last_response': '2024-03-20T06:45:10.366219+02:00'},
#   {'registration': 'BX07CGGPFM',
#    'make': 'Ford',
#    'model': 'Ranger',
#    'color': 'White',
#    'chassis_number': 'AFANXXMJ2NCA35785',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'CW064583',
#    'terminal_last_response': '2024-03-22T07:55:20.809919+02:00'},
#   {'registration': 'TEMP-1326741TT',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'AHTSS22P507142170CXXX',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF072763',
#    'terminal_last_response': '2024-03-23T13:04:40.421424+02:00'},
#   {'registration': 'FXN987L',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'AHTSS22P507142170CXX',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'RQ026567',
#    'terminal_last_response': '2024-03-23T13:05:09.633262+02:00'},
#   {'registration': 'TEMP-1344912',
#    'make': 'Volkswagen',
#    'model': 'Golf',
#    'color': 'Red',
#    'chassis_number': 'WVWZZZAUZHW317638',
#    'model_year': 2018,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE017265',
#    'terminal_last_response': '2024-03-25T04:09:19.685414+02:00'},
#   {'registration': 'NVD561GPCT9',
#    'make': 'Nissan',
#    'model': 'UD80',
#    'color': 'White',
#    'chassis_number': 'ADDT5300000001905',
#    'model_year': 2023,
#    'contract_status': 'Active',
#    'terminal_serial': 'RN010241',
#    'terminal_last_response': '2024-03-26T09:57:03.628368+02:00'},
#   {'registration': 'NVD561GP',
#    'make': 'Nissan',
#    'model': 'UD80',
#    'color': 'White',
#    'chassis_number': 'ADDT5300000001905',
#    'model_year': 2002,
#    'contract_status': 'Active',
#    'terminal_serial': 'BH023405',
#    'terminal_last_response': '2024-03-26T10:02:34.023484+02:00'},
#   {'registration': 'NVD561GPQ',
#    'make': 'Nissan',
#    'model': 'UD80',
#    'color': 'White',
#    'chassis_number': 'ADDT5300000001905Q',
#    'model_year': 2002,
#    'contract_status': 'Active',
#    'terminal_serial': 'CY658650',
#    'terminal_last_response': '2024-03-26T10:16:07.894161+02:00'},
#   {'registration': 'BD55SBZN',
#    'make': 'Ford',
#    'model': 'Ranger',
#    'color': 'White',
#    'chassis_number': 'AFAPXXMJ2PKU58411',
#    'model_year': 2020,
#    'contract_status': 'Active',
#    'terminal_serial': 'BL015496',
#    'terminal_last_response': '2024-03-28T04:01:37.729240+02:00'},
#   {'registration': 'KC93VZGPNEW',
#    'make': 'Big Boy',
#    'model': 'Velocity 150cc',
#    'color': 'White',
#    'chassis_number': 'FLEYPCKT47M1001221',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'RE063201',
#    'terminal_last_response': '2024-03-28T12:03:14.149866+02:00'},
#   {'registration': 'HY05YTGPFML',
#    'make': 'Isuzu',
#    'model': 'FTR850',
#    'color': 'White',
#    'chassis_number': 'ACVFTR34H8N026170FML',
#    'model_year': 2019,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE236871',
#    'terminal_last_response': '2024-03-28T17:43:18.699049+02:00'},
#   {'registration': 'HY05YTGPQ',
#    'make': 'Isuzu',
#    'model': 'FTR850',
#    'color': 'White',
#    'chassis_number': 'ACVFTR34H8N026170Q',
#    'model_year': 2019,
#    'contract_status': 'Active',
#    'terminal_serial': 'CY355636',
#    'terminal_last_response': '2024-03-28T17:43:48.792859+02:00'},
#   {'registration': 'HY05YTGPCT9',
#    'make': 'Isuzu',
#    'model': 'FTR850',
#    'color': 'White',
#    'chassis_number': 'ACVFTR34H8N026170',
#    'model_year': 2019,
#    'contract_status': 'Active',
#    'terminal_serial': 'RQ030326',
#    'terminal_last_response': '2024-03-28T17:43:57.060179+02:00'},
#   {'registration': 'HJW137NWCXD',
#    'make': 'Jeep',
#    'model': 'Cherokee',
#    'color': 'White',
#    'chassis_number': '1J8G458539W554331CXD',
#    'model_year': 2010,
#    'contract_status': 'Active',
#    'terminal_serial': 'CX1061603',
#    'terminal_last_response': '2024-03-30T18:50:31.089383+02:00'},
#   {'registration': 'BW05HYGP',
#    'make': 'Toyota',
#    'model': 'HILUX 2.5D-4D SRX R/B',
#    'color': 'WHITE',
#    'chassis_number': 'AHTCR32G508016973',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'CT821758',
#    'terminal_last_response': '2024-03-31T11:52:02.722251+02:00'},
#   {'registration': 'FWD622MP',
#    'make': 'Volkswagen',
#    'model': 'Golf',
#    'color': 'BLUE',
#    'chassis_number': 'WVWZZZ1KZCW342618',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'CA097310',
#    'terminal_last_response': '2024-03-31T13:16:31.529351+02:00'},
#   {'registration': 'EX3002904',
#    'make': 'Hino',
#    'model': 'Hino 300 Series',
#    'color': 'White',
#    'chassis_number': 'AHHUCK1F501001143',
#    'model_year': 2023,
#    'contract_status': 'Active',
#    'terminal_serial': 'EF200120',
#    'terminal_last_response': '2024-03-31T20:43:35.759743+02:00'},
#   {'registration': 'DWR235EC(FL)',
#    'make': 'Volkswagen',
#    'model': 'Caddy',
#    'color': 'White',
#    'chassis_number': 'WV1ZZZ2KZ8X017889',
#    'model_year': 2007,
#    'contract_status': 'Active',
#    'terminal_serial': 'CD030131',
#    'terminal_last_response': '2024-04-01T07:40:48.582341+02:00'},
#   {'registration': 'DWR235EC',
#    'make': 'Volkswagen',
#    'model': 'Caddy 1.6',
#    'color': 'White',
#    'chassis_number': 'WV1ZZZ2KZ8X017889',
#    'model_year': 2007,
#    'contract_status': 'Active',
#    'terminal_serial': 'CT821743',
#    'terminal_last_response': '2024-04-01T21:01:51.257938+02:00'},
#   {'registration': 'RKL453GP',
#    'make': 'Nissan',
#    'model': 'Hardbody',
#    'color': 'White',
#    'chassis_number': 'ADNJ420000E013864',
#    'model_year': 2004,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE255283',
#    'terminal_last_response': '2024-04-02T07:57:44.001355+02:00'},
#   {'registration': 'RKL453GPS1',
#    'make': 'Nissan',
#    'model': 'Hardbody',
#    'color': 'White',
#    'chassis_number': 'ADNJ420000E013864S1',
#    'model_year': 2004,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE262511',
#    'terminal_last_response': '2024-04-02T07:57:44.384345+02:00'},
#   {'registration': 'BOSSIEWP',
#    'make': 'Toyota',
#    'model': 'Fortuner',
#    'color': 'Gold',
#    'chassis_number': 'AHTZZ69G405022721',
#    'model_year': 2011,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE218079',
#    'terminal_last_response': '2024-04-02T08:48:28.615346+02:00'},
#   {'registration': 'BOSSIEWP1MN',
#    'make': 'Toyota',
#    'model': 'Fortuner',
#    'color': 'Gold',
#    'chassis_number': 'AHTZZ69G4050227211MN',
#    'model_year': 2011,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE218118',
#    'terminal_last_response': '2024-04-02T08:48:29.028508+02:00'},
#   {'registration': 'FHK284MP(FM)',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTCR32G208011150',
#    'model_year': 2010,
#    'contract_status': 'Active',
#    'terminal_serial': 'CW088471',
#    'terminal_last_response': '2024-04-02T08:52:38.363988+02:00'},
#   {'registration': 'CC53KMGPCT9',
#    'make': 'Nissan',
#    'model': 'UD40',
#    'color': 'White',
#    'chassis_number': 'ADDM03000000050955',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'RE048443',
#    'terminal_last_response': '2024-04-02T10:37:16.098702+02:00'},
#   {'registration': 'BL20JCGP',
#    'make': 'Toyota',
#    'model': 'HILUX D4D',
#    'color': 'WHITE ',
#    'chassis_number': 'AHTEZ39G107023472',
#    'model_year': 2011,
#    'contract_status': 'Active',
#    'terminal_serial': 'CT994536',
#    'terminal_last_response': '2024-04-02T11:36:34.554275+02:00'},
#   {'registration': 'BW48YHGPCTGW',
#    'make': 'Isuzu',
#    'model': 'KB300 LE',
#    'color': 'White',
#    'chassis_number': 'ADM2RD85CA4593760',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'CW053502',
#    'terminal_last_response': '2024-04-02T15:43:14.701780+02:00'},
#   {'registration': 'CC53KSGPQ',
#    'make': 'Nissan',
#    'model': 'UD440',
#    'color': 'White',
#    'chassis_number': 'ADDM03000000050958Q',
#    'model_year': 2012,
#    'contract_status': 'Active',
#    'terminal_serial': 'CY506137',
#    'terminal_last_response': '2024-04-03T16:45:51.003499+02:00'},
#   {'registration': 'FDY159EC(FL)',
#    'make': 'Volkswagen',
#    'model': 'Caddy 1.6',
#    'color': 'White',
#    'chassis_number': 'WVIZZZ2KZ9X077787T',
#    'model_year': 2009,
#    'contract_status': 'Active',
#    'terminal_serial': 'CW054411',
#    'terminal_last_response': '2024-04-03T17:32:00.583493+02:00'},
#   {'registration': 'HX68RWGPQ',
#    'make': 'Isuzu',
#    'model': 'FTR850',
#    'color': 'White',
#    'chassis_number': 'ACVFTR34H8N026064Q',
#    'model_year': 2019,
#    'contract_status': 'Active',
#    'terminal_serial': 'CY701268',
#    'terminal_last_response': '2024-04-04T07:15:23.446443+02:00'},
#   {'registration': 'V4TESTSERVER43',
#    'make': 'Toyota',
#    'model': 'Tazz',
#    'color': 'Black',
#    'chassis_number': 'V4TESTSERVER43',
#    'model_year': 1955,
#    'contract_status': 'Active',
#    'terminal_serial': 'EF097990',
#    'terminal_last_response': '2024-04-04T11:17:52.523278+02:00'},
#   {'registration': '12DEM498777S1-THINUS',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White, metallic',
#    'chassis_number': 'AHTJB3DC704498777S1',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'BG060823',
#    'terminal_last_response': '2024-04-05T03:14:13.330124+02:00'},
#   {'registration': '25UFC59225S1',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'ANTCW8CB101963509S1',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'BG057345',
#    'terminal_last_response': '2024-04-05T03:17:41.817817+02:00'},
#   {'registration': 'LB31HFGP',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTBA3CD206245243',
#    'model_year': 2023,
#    'contract_status': 'Active',
#    'terminal_serial': 'CD178924',
#    'terminal_last_response': '2024-04-05T03:54:55.489763+02:00'},
#   {'registration': 'TEMP-1326741AA',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'AHTSS22P507142170CXAA',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'BG021448',
#    'terminal_last_response': '2024-04-05T03:57:13.044610+02:00'},
#   {'registration': '76UFP81994S2',
#    'make': 'Volkswagen',
#    'model': 'Golf',
#    'color': 'Red',
#    'chassis_number': 'WVWZZZAUZHW317638S2',
#    'model_year': 2018,
#    'contract_status': 'Active',
#    'terminal_serial': 'BG028766',
#    'terminal_last_response': '2024-04-05T04:54:36.547012+02:00'},
#   {'registration': 'EV3009802S1',
#    'make': 'Hino',
#    'model': 'Hino 300 Series',
#    'color': 'White',
#    'chassis_number': 'AHHACK3F401002817S1',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'BG073211',
#    'terminal_last_response': '2024-04-05T06:14:15.009302+02:00'},
#   {'registration': 'LB31HFGPA',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTBA3CD206245243A',
#    'model_year': 2023,
#    'contract_status': 'Active',
#    'terminal_serial': 'BG037460',
#    'terminal_last_response': '2024-04-05T06:14:17.580390+02:00'},
#   {'registration': '78VIV12716S2',
#    'make': 'Volkswagen',
#    'model': 'Polo Vivo',
#    'color': 'Blue',
#    'chassis_number': 'AAVZZZ6R9RU008567S2',
#    'model_year': 2023,
#    'contract_status': 'Active',
#    'terminal_serial': 'BG057642',
#    'terminal_last_response': '2024-04-05T06:31:41.265076+02:00'},
#   {'registration': 'EV3009802',
#    'make': 'Hino',
#    'model': 'Hino 300 Series',
#    'color': 'White',
#    'chassis_number': 'AHHACK3F401002817',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'EG007612',
#    'terminal_last_response': '2024-04-05T07:05:47.116469+02:00'},
#   {'registration': 'EX3002904S1',
#    'make': 'Hino',
#    'model': 'Hino 300 Series',
#    'color': 'White',
#    'chassis_number': 'AHHUCK1F501001143S1',
#    'model_year': 2023,
#    'contract_status': 'Active',
#    'terminal_serial': 'BG020870',
#    'terminal_last_response': '2024-04-05T07:28:12.963130+02:00'},
#   {'registration': '70HIA201550',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'JTFSS23PX00201550',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'BL019104',
#    'terminal_last_response': '2024-04-05T08:47:26.813495+02:00'},
#   {'registration': '70HIL538096S1',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTBA3CC206538096S1',
#    'model_year': 2023,
#    'contract_status': 'Active',
#    'terminal_serial': 'BG065195',
#    'terminal_last_response': '2024-04-05T08:55:23.445825+02:00'},
#   {'registration': 'LR72GDGPBU',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTAA3DD501734632BU',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'BL041052',
#    'terminal_last_response': '2024-04-05T10:08:15.085351+02:00'},
#   {'registration': 'KMR030MPBU',
#    'make': 'Toyota',
#    'model': 'Fortuner',
#    'color': 'White',
#    'chassis_number': 'AHTJA3GS200230149BU',
#    'model_year': 2018,
#    'contract_status': 'Active',
#    'terminal_serial': 'BF197764',
#    'terminal_last_response': '2024-04-05T10:08:26.875639+02:00'},
#   {'registration': '70DEM16504S1',
#    'make': 'Toyota',
#    'model': 'Fortuner',
#    'color': 'Silver',
#    'chassis_number': 'AHTJA3GS900244632S1',
#    'model_year': 2022,
#    'contract_status': 'Active',
#    'terminal_serial': 'BG032015',
#    'terminal_last_response': '2024-04-05T10:18:14.818045+02:00'},
#   {'registration': '25HIA13994',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'AHTSX22P607113181',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'BE267092',
#    'terminal_last_response': '2024-04-05T11:13:06.035945+02:00'},
#   {'registration': 'TEMP-1551900BU',
#    'make': 'Toyota',
#    'model': 'Hilux',
#    'color': 'White',
#    'chassis_number': 'AHTJB3DC70449934BU',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'BH154688',
#    'terminal_last_response': '2024-04-05T11:22:10.259724+02:00'},
#   {'registration': 'KC93VZGPNEWBR',
#    'make': 'Big Boy',
#    'model': 'Velocity 150cc',
#    'color': 'White',
#    'chassis_number': 'FLEYPCKT47M1001221BR',
#    'model_year': 2024,
#    'contract_status': 'Active',
#    'terminal_serial': 'BG049152',
#    'terminal_last_response': '2024-04-05T12:35:12.712737+02:00'},
#   {'registration': 'TEMP-1164363AA',
#    'make': 'Toyota',
#    'model': 'Quantum',
#    'color': 'White',
#    'chassis_number': 'AHTSS22P707129579',
#    'model_year': 2021,
#    'contract_status': 'Active',
#    'terminal_serial': 'BG004469',
#    'terminal_last_response': '2024-04-05T12:47:12.818316+02:00'},
#   {'registration': 'FDY159EC',
#    'make': 'Volkswagen',
#    'model': 'Caddy 1.6',
#    'color': 'White',
#    'chassis_number': 'WVIZZZ2KZ9X077787',
#    'model_year': 2009,
#    'contract_status': 'Active',
#    'terminal_serial': 'CT991532',
#    'terminal_last_response': '2024-04-05T13:22:24.571152+02:00'},
#   {'registration': 'WSR743GP',
#    'make': 'Toyota',
#    'model': 'Yaris',
#    'color': 'Blue',
#    'chassis_number': 'JTDKW923905086740',
#    'model_year': 2007,
#    'contract_status': 'Cancelled',
#    'terminal_serial': None,
#    'terminal_last_response': None},
#   {'registration': 'HADEBE-TEMP',
#    'make': 'Opel',
#    'model': 'Combo',
#    'color': 'Black,Silver',
#    'chassis_number': None,
#    'model_year': 1906,
#    'contract_status': 'Cancelled',
#    'terminal_serial': None,
#    'terminal_last_response': None},
#   {'registration': 'BRS768NC',
#    'make': 'Volkswagen',
#    'model': 'Polo Classic',
#    'color': 'Dark Green',
#    'chassis_number': None,
#    'model_year': 1999,
#    'contract_status': 'Fitment Pending',
#    'terminal_serial': None,
#    'terminal_last_response': None}],
#  'sim_card': {'chip_id': '65739879'},
#  'fitment': {'date': '2024-05-17 10:10:19.574118+02',
#   'fitter_name': 'Abel Tafadzwa'},
#  'billing': {'product_package': 'CT9 Mobile Extended Battery',
#   'recovery_option': 'true'}}

# %%
client_data.get("account_overview")
# Out:
# {'user_id': '83906',
#  'user_name': 'OELO00016',
#  'client': 'Linda Oelofse',
#  'client_type': 'Individual',
#  'intro_date': '2004-12-30',
#  'last_successful_payment_date': '2025-04-24',
#  'percentage_total_billing': '28.04',
#  'total_invoices': '5670.0000',
#  'total_paid': '1590.0000',
#  'monthly_debit_order_total': '10535.69',
#  'vehicle_count_total': '61',
#  'vehicle_count_active': '59',
#  'payment_status': '',
#  'run_status': 'Dated',
#  'naedo_tracking': 'No',
#  'naedo_special': 'No',
#  'sale_agent': 'East Rand Toyota',
#  'account_status': 'Active',
#  'payment_arrangement': 'Broken Promise',
#  'debit_order_date': '1st',
#  'debit_order_logic': 'Client',
#  'service_status': 'Active',
#  'rating': '5',
#  'last_agent_contact_date': '',
#  'last_agent_contact': '',
#  'department': 'Terminated',
#  'responsible_agent': 'Karabo Dire',
#  'cancellation_fee_charged': 'No',
#  'letter_of_demand_history': '',
#  'contactable': 'Yes',
#  'contact_details_valid': 'Valid Contact Details',
#  'bank_updated': 'Yes',
#  'bank_invalid': 'Valid',
#  'allow_debit_order': 'Yes',
#  'subscription': '10535.6900',
#  'next_invoice_date': '2025-06-01',
#  'last_invoice_date': '2025-04-01',
#  'technical_issue': 'Yes',
#  'disputes': 'No',
#  'cancellation_fee': '27325.2300',
#  'invoice_not_raised': '0',
#  'invoice_not_raised_from': '',
#  'disputes_historic': 'No',
#  'suspend_billing': 'No',
#  'blacklisted': 'No',
#  'blacklisted_date': '',
#  'lastdisposition': '2025/04/02 18:18: Call back',
#  'mandate': 'N/A',
#  'rating_colour': 'Platinum',
#  'special_instruction': '',
#  'tax_reg_number': '',
#  'employer': 'Self-Employed',
#  'collection_instruction': ''}

# %%
client_data.get("account_aging")
# Out:
# {'x0': '0.0000',
#  'x30': '4030.0000',
#  'x60': '0.0000',
#  'x90': '0.0000',
#  'x120': '0.0000',
#  'xbalance': '4030.0000'}

# %%
import importlib
import src.Agents.call_center_agent.prompts as prompts
from src.Agents.call_center_agent.call_scripts import ScriptType
from src.Agents.call_center_agent.state import CallStep,VerificationStatus

call_step = CallStep.NAME_VERIFICATION.value

parameters = prepare_parameters(
    client_data,
    current_step=call_step,
    state={
        'name_verification_status': VerificationStatus.VERIFIED.value
    },
    script_type=ScriptType.RATIO_1_INFLOW.value,
    agent_name="AI Agent"
)
# print(parameters)

prompt = prompts.get_step_prompt(call_step,parameters)
print(prompt)
# print(prompts.NAME_VERIFICATION_PROMPT)
# Out:
# 2025-05-26 19:27:31,778 - INFO - Prepared parameters for step: name_verification
# You are AI Agent, a professional debt collection agent for Cartrack's Accounts Department making an OUTBOUND CALL.
# You are calling regarding an account matter but CANNOT discuss account details until identity is verified.
# Keep responses concise (max 20 words) and professional but firm.
#
# ## YOUR TASK
# Confirm you're speaking with the correct person based on their response.
#
# ## CURRENT STATUS
# - Attempt: 1/3
# - Status: VERIFIED
#
# ## RESPONSE STRATEGY
# **INSUFFICIENT_INFO**: Ask for name confirmation
# - First: "Is this Linda I'm speaking with?"
# - Later: "For security, I need to confirm this is Linda Oelofse"
#
# **VERIFIED**: Brief acknowledgment, transition to security notice
# **THIRD_PARTY**: Provide callback message per script
# **UNAVAILABLE**: Acknowledge and provide callback number
# **WRONG_PERSON**: Apologize briefly, end call (no details)
#
# ## IMPORTANT
# - Do NOT mention outstanding amounts or account details
# - Do NOT discuss why you're calling until identity is verified
# - Keep responses focused on identity confirmation only
#
# ## SCRIPT REFERENCE
# May I speak to Linda Oelofse, please?
#
# ## GOAL
# Confirm identity or handle non-target responses appropriately.
# NO account information until verified.

# %%
import importlib
import src.Agents.call_center_agent.prompts
importlib.reload(src.Agents.call_center_agent.prompts)
from src.Agents.call_center_agent.data_parameter_builder import prepare_parameters
from src.Agents.call_center_agent.call_scripts import ScriptType

# print(NAME_VERIFICATION_PROMPT)
print("="*50)
parameters = build_real_data_parameters(
    user_id="83906",
    current_step="details_verification",
    state={
    },
    script_type=ScriptType.RATIO_1_INFLOW.value,
    agent_name="AI Agent"
)
# print(parameters)

prompt = get_step_prompt("details_verification", parameters)

print(prompt)
# Out:
# 2025-05-26 15:27:29,946 - INFO - Built parameters for 83906, step: details_verification
# ==================================================
#
#
# You are John Smith, a professional debt collection agent for Cartrack's Accounts Department making an OUTBOUND CALL.
# You are calling regarding an account matter but CANNOT discuss account details until identity is verified.
# Keep responses concise (max 20 words) and professional but firm.
#
#
# ## YOUR TASK FOR THIS STEP
# 1. Verify client's identity through security information for data protection compliance
# 2. Request ONLY ONE verification item at a time: currently **verification information**
# 3. Track successful verifications: []
# 4. Continue until requirements met: ID/passport OR three verification items
# 5. Use direct questions without listing multiple options
#
# ## CURRENT VERIFICATION STATUS
# - **Attempt:** 1/5
# - **Currently requesting:** verification information
# - **Already verified:** []
# - **Status:** INSUFFICIENT_INFO
#
# ## VERIFICATION REQUIREMENTS
# Client must provide EITHER:
# - **Option A:** Full ID number or passport number (single item sufficient)
# - **Option B:** THREE items from: username, vehicle registration, make, model, color, email address
#
# ## YOUR APPROACH BY ATTEMPT
#
# ### First Attempt:
# - Include security notice about call recording
# - Ask for current verification item only
# - Example: "Please note that this call is recorded for quality and security purposes. To ensure I'm speaking with the right person, could you please confirm your verification information?"
#
# ### Follow-up Attempts:
# - Proceed directly to verification request
# - Keep questions brief and specific
# - Examples:
#   - "Thank you. Could you please confirm your verification information?"
#   - "I'll need to verify one more detail. What is your verification information?"
#
# ## CRITICAL CONSTRAINTS
# - **DO NOT** mention outstanding amounts or account details
# - **DO NOT** discuss why you're calling until identity is FULLY verified
# - **DO NOT** list multiple verification options at once
# - **DO NOT** introduce yourself again (greetings already completed)
# - **ONLY** ask for the specific field indicated: verification information
#
# ## SCRIPT REFERENCE
# Please note that this call is recorded for quality and security purposes. To ensure I am speaking to the right person, please confirm the following details:
#     - Username, Date of birth, Vehicle registration, Vehicle Make, Vehicle Model,
#     - Vehicle colour, VIN Number, Email address, Residential Address, Contact Number,
#     - Full ID number (alone sufficient), Full Passport number (alone sufficient)
#
# ## VERIFICATION COMPLETION
# Only proceed to account discussion after:
# - Full ID/passport number provided, OR
# - Three verification items successfully confirmed
#
# ## GOAL
# Complete identity verification to ensure data protection compliance before discussing any financial or account matters. NO account information until FULLY verified.

# %%
get_name_verification_prompt({})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_name_verification_prompt({})
#
# File ~/Documents/Langgraph/00_AudioProject/02_Call_Center_AI_Agent/src/Agents/call_center_agent/prompts.py:498, in get_name_verification_prompt(parameters)
#     497 def get_name_verification_prompt(parameters: Dict[str, Any]) -> str:
# --> 498     return get_step_prompt("name_verification", parameters)
#
# File ~/Documents/Langgraph/00_AudioProject/02_Call_Center_AI_Agent/src/Agents/call_center_agent/prompts.py:477, in get_step_prompt(step_name, parameters)
#     474 # Choose appropriate base context based on verification status
#     475 if step_name in ["introduction", "name_verification", "details_verification"] or not is_fully_verified:
#     476     # Use unverified context (no sensitive info)
# --> 477     base_context = BASE_AGENT_CONTEXT_UNVERIFIED.format(**parameters)
#     478 else:
#     479     # Use verified context (full client info available)
#     480     base_context = BASE_AGENT_CONTEXT_VERIFIED.format(**parameters)
#
# KeyError: 'agent_name'

# %% [markdown]
# ### Console View

# %%
from src.Database.CartrackSQLDatabase import *
import json
user_id = 11419
number_records=1
client_type='Individual'
min_age_days=0
max_age_days=10
min_balance_total=100
invoice_option="All"
payment_arrangement_status = "Active"
pre_legal=None
rejected=None
sort_by="balance_total"
sort_direction="DESC"

result = get_debtor_age_analysis.invoke({
    'number_records':number_records,
    'user_id':user_id,
    'client_type':client_type,
    'min_age_days':min_age_days,
    'max_age_days':max_age_days,
    'min_balance_total':min_balance_total,
    'invoice_option':invoice_option,
    'payment_arrangement_status': payment_arrangement_status,
    'pre_legal':pre_legal,
    'rejected':rejected,
    'sort_by':"balance_total",
    'sort_direction':"DESC",
    'payment_arrangement_status':payment_arrangement_status
})
print(json.dumps(result, indent=2))
# user_id = '11419'
# get_client_billing_analysis.invoke(user_id)

# %%
user_id = '28173'
# get_client_profile.invoke(user_id)

sql_query = f"Select ct.calc_outstanding('{user_id}')" 
sql_query = f"Select ct.get_debtor_info('{user_id}')"


db.execute_function_and_extract_output('ct','sp_debtors_client_info',user_id )

# %%
get_client_account_overview.invoke(user_id)

# %%
from src.Database.CartrackSQLDatabase import *

user_id = '28173'
# get_client_identity_details.invoke(user_id)
get_client_profile.invoke(user_id)

# %% [markdown]
# ### Individual

# %%
from src.Database.CartrackSQLDatabase import *

user_id = '28173'
get_client_account_overview.invoke(user_id)

# %%
#Account Detail
get_client_banking_details.invoke(user_id)

# %%
## console view
from src.Database.CartrackSQLDatabase import *
import json
user_id = '1400424'
# user_id = '70997'
# user_id = "963262"
# user_id = "10003"
# user_id= '1035923'


###### Indi
# get_client_vehicle_info.invoke(user_id)
# get_client_identity_details.invoke(user_id)
# print(json.dumps(get_client_profile.invoke(user_id),indent=2))

# #Step 3: reason for call
# get_client_account_aging.invoke(user_id)
# get_client_account_status.invoke(user_id)
# get_client_billing_analysis.invoke(user_id)

# #Step 4: Negotiation
# print(json.dumps(get_client_contracts.invoke(user_id),indent=2))

# #Step 5: Promise to pay (PTP)
# get_client_account_statement.invoke(user_id)
# get_client_banking_details.invoke(user_id)
# get_client_payment_history.invoke(user_id)
# get_client_debit_mandates.invoke(user_id)

# update_payment_arrangements.invoke(user_id)

# get_payment_arrangement_types.invoke("")

# %%
# create_payment_arrangement(
#             db=custom_db,  # Your database connection
#             user_id=user_id,  # Example user ID
#             note="Payment arrangement test",
#             followup_date="2025-05-13",
#             pay_type_id=1,  # Direct debit
#             payment1=500.00,
#             date1="2025-05-11",  # First payment
#             # payment2=450.00,
#             # date2="2025-06-18"   # Second payment (optional)
#         )

# create_payment_arrangement_payment_portal(
#             db=custom_db,
#             user_id=user_id,
#             payment_type_id=1,
#             payment_date="2025-05-17",
#             amount=500.00,
#         )
# generate_sms_payment_url(
#     db=custom_db,  # Your database connection
#     user_id=user_id,  # Example user ID
#     amount=500.00,  # Payment amount
#     utm_source="sms",  # Tracking parameter
#     utm_medium="collection"  # Tracking parameter
# )

# validate_next_of_kin_contact(
#     db=custom_db,  # Your database connection
#     user_id=user_id,  # Example client ID
#     name="John Smith",  # Next of kin name
#     phone="+27123456789",  # Next of kin phone number
#     email="john.smith@example.com"  # Next of kin email
# )

# validate_next_of_kin_emergency_contact(
#     db=custom_db,  # Your database connection
#     vehicle_id=5421,  # Example vehicle ID 
#     contact_priority=1,  # Primary contact (highest priority)
#     name="Jane Smith",  # Contact name
#     phone="+27123456789",  # Contact phone number
#     email="jane.smith@example.com"  # Contact email
# )

# %%
create_payment_arrangement(
    db=custom_db,
    user_id=user_id,
    note="Test payment arrangement for update test",
    followup_date="2025-05-12",
    pay_type_id=2,
    payment1=100.00,  
    date1="2025-05-12"
)
update_result = update_payment_arrangements(custom_db, user_id)

# %%
# Import required modules
import datetime
# Create a Promise to Pay for R550.00 on April 15, 2025
arrangement_id = create_debit_order_arrangement(
    db=custom_db,
    user_id=user_id,
    amount=550.00,
    payment_date="2025-05-09",
    currency_symbol="R",
)

if arrangement_id:
    print(f"Successfully created arrangement #{arrangement_id}")
else:
    print("Failed to create arrangement")

# %%
custom_db._execute('select * from ct.arrangement_pay limit 10')

# %% [markdown]
# ### B. Tools Test

# %% [markdown]
# #### 01 - Tool - retrieve_client_details

# %% [markdown]
# Single Test

# %%
from src.Tools import retrieve_client_details

# Test with different user IDs
user_ids = [
     "107620",
     "28173",
     "1688715",
     "1295163"
]

index = 3
result = retrieve_client_details.invoke({"user_id": user_ids[index], "db_cartrack":custom_db})
result

# %% [markdown]
# Test cases

# %%
from testcases.tester_class.ClientDetailsRetrievalTester import ClientDetailsRetrievalTester, test_cases

# #
# # Create tester instance
tester = ClientDetailsRetrievalTester(retrieve_client_details, custom_db )

# # Run all predefined tests
tester.run_all_tests(test_cases)

# # # Export results (optional)
# # tester.export_results()

# # # Or run individual custom test
# # custom_result = tester.run_test(
# #     user_id=107622,
# #     expected_attributes={"full_name": "Jane Smith"}
# # )
test_cases

# %% [markdown]
# #### 02 - Tool - verify_client_name

# %% [markdown]
# Single test

# %%
# from src.Tools import verify_client_name
from src.Agents.call_center.tools.verify_client_name import verify_client_name
from langchain_core.messages import HumanMessage, AIMessage
##########################################################################
# Simple test
##########################################################################
client_full_name = "John Doe"

messages = [
    AIMessage(content=f"Hello, am I speaking with {client_full_name}?"),
    HumanMessage(content="Yes, this is Johny speaking."),
    # HumanMessage(content="No, I'm his wife. He's not available right now."),
    # HumanMessage(content="Yes, that's me, but I'm driving. Can you call later?"),

]

# Call the function with the correct parameter structure
result = verify_client_name.invoke(
    {'client_full_name': client_full_name, 'messages': messages}
)

print(f"Classification: {result['classification']}")
# print(f"Reasoning: {result['reasoning']}")
# print(f"Suggested Response: {result['suggested_response']}")
print(f"Name Variants: {result['name_variants_detected']}")

# %% [markdown]
# Many test cases

# %%
from testcases.tester_class.ClientNameVerificationTester import  ClientNameVerificationTester, test_cases
# # Create tester instance
tester = ClientNameVerificationTester(verify_client_name, default_max_failed_attempts=4, verbose=False)

# # Run all predefined tests (without session state maintenance)
# tester.run_all_tests(test_cases)

# Optional: Run with session state maintenance for sequential tests
tester.run_all_tests(test_cases[:])

# Optional: Export results
# tester.export_results()

# Optional: Generate detailed report
# tester.generate_detailed_report()

# %% [markdown]
# #### 03 - Tool - verify_client_details

# %%
# from src.Tools import verify_client_details
from typing_inspect import get_args

from src.Agents.call_center.tools.verify_client_details import verify_client_details, verification_fields

from langchain_core.messages import HumanMessage, AIMessage

client_details = {
        "username": "jsmith2023",
        "vehicle_registration": "ABC123GP",
        "vehicle_make": "Toyota",
        "vehicle_model": "Corolla",
        "vehicle_color": "Blue",
        "email": "john.smith@example.com",
        "id_passport": "8305125392086"
    }

conversation_3factor = [
        # AIMessage(content="Good day, you are speaking to Sarah from the Cartrack Accounts Department. May I speak to John Smith please."),
        # HumanMessage(content="Yes, this is John speaking."),
        AIMessage(content="Thank you for confirming. For security purposes, could you please verify 3 of the following: your username, vehicle registration, vehicle make, model, color, email, or your ID number?"),
        HumanMessage(content="Sure, I have a blue Toyota Corolla. The license plate is ABC123GP."),
        AIMessage(content="Thank you. Could you provide one more detail for verification?"),
        HumanMessage(content="My email is john.smith@example.com"),
    ]
result = verify_client_details.invoke({
            "client_details": client_details,
            "messages": conversation_3factor,
            "required_match_count": 3,
            "max_failed_attempts": 3
        })
result

# list(get_args(verification_fields))[:-2]

# %%
from testcases.tester_class.ClientDetailsVerificationTester import ClientDetailsVerificationTester, test_cases
tester = ClientDetailsVerificationTester(verify_client_details,default_required_matches=3, verbose=True)

# Run all predefined tests
tester.run_all_tests(test_cases)

# Optional: Export results
# tester.export_results()

# %% [markdown]
# ### C. Agent Loading

# %%
# from langchain_core.messages import HumanMessage,AIMessage
# messages = [HumanMessage(content="Hello, I am Trung"),
# AIMessage(content="Hello Trung! Nice to meet you. How can I assist you today? Whether you have questions, need information on a particular topic, or just want to chat about something interesting, feel free to let me know"),
#     HumanMessage(content="What is my Name")
# ]
# agent.llm.invoke(messages).content

# %%
from app_config import CONFIG
from src.Agents import CallCenterAgent

# Create a new instance with with thread for persist memmory
config = CONFIG.copy()
config["configurable"]={"thread_id": 1}

agent = CallCenterAgent(config)

# %%
from IPython.display import Image, display
display(Image(agent.workflow.get_graph().draw_mermaid_png()))

# %%
print(agent.workflow.get_state(agent.config).values['messages'][-1].content)
for msg in agent.workflow.get_state(agent.config).values['messages']:
    msg.pretty_print()

# %%
# Assuming you're in the context of the CallCenterAgent class
from src.Agents.agent00_debtor_call_center import  CallCenterAgentState, VerificationStatus, CallStep
from src.CallScripts.call_scripts import *
from langchain_core.messages import HumanMessage, AIMessage
# Create a sample state for testing
state = CallCenterAgentState(
    # Verification details
    name_verification_status=VerificationStatus.INSUFFICIENT_INFO.value,
    name_verification_attempts=1,
    details_verification_status=VerificationStatus.INSUFFICIENT_INFO.value,
    details_verification_attempts= 0,
    verified_client_name="John Doe",
    
    # Call flow state
    current_call_step=CallStep.NAME_VERIFICATION.value,
    previous_step=None,
    is_call_ended=False,
    
    # Client information tracking
    call_info={
        "client_details": {
            "user_id": 12345,
            "full_name": "John Doe",
            "email": "john.doe@example.com"
        }
    },
    
    # Payment and context information
    payment_details={},
    payment_method=None,
    agreed_amount="R 00,850.00",
    
    # Additional flags
    query_detected=False,
    has_referrals=False,
    cancellation_requested=False,
    escalation_requested=False,
    
    # Messages (optional, but can help with context)
    messages=[
        HumanMessage(content="Hello, this is John Doe."),
        AIMessage(content="Good day, I'm calling from Cartrack regarding your account.")
    ]
)

# Before generating the prompt, set up client info
agent.client_info = {
    "user_id": 12345,
    "full_name": "John Doe",
    "email": "john.doe@example.com",
    "outstanding_amount": "R 22,850.00",
    "account_status": "Overdue",
    "vehicles": [
        {
            "make": "Toyota",
            "model": "Corolla",
            "registration": "ABC123GP"
        }
    ],
    "subscription_amount": "R 250.00",
    "subscription_date": "25th of each month",
    "cancellation_value": "R 500.00",
    "total_balance": "R 2,350.00"
}

# Set default client name
agent.default_client_name = "John Doe"

# Set script type (optional)
agent.script_type = ScriptType.RATIO_1_INFLOW
state["current_call_step"]=CallStep.REASON_FOR_CALL.value
agent._process_introduction(state)

# %%
scrip_types = [item for item in ScriptType]
    

for step in CallStep:
    print("="*85)
    print("="*10, step,"="*50 )
    agent.script_type = scrip_types[0]
    state["current_call_step"]=step.value
    # print(agent._create_dynamic_system_prompt(state))
    agent._process_introduction(state)

# %%
agent.set_logging(False)
agent.set_debug_mode(False)


config["configurable"]= {"thread_id":2}
agent.config = config

_=agent.process_message("yes I am")

# _=agent.process_message("I dont have information")

# %%
"""
Demo script showing how to use the refactored LLM-driven Call Center Agent.
"""

from call_center_agent import CallCenterAgent
from call_center_enums import CallStep, VerificationStatus, PaymentMethod
from langchain_openai import ChatOpenAI

def create_demo_agent():
    """
    Create a demo agent with sample configuration.
    
    Returns:
        Configured CallCenterAgent instance
    """
    # Create LLM - replace with your preferred LLM
    llm = ChatOpenAI(
        model="gpt-4",  # Can replace with whatever model you prefer
        temperature=0.3
    )
    
    # Sample client details
    client_details = {
        "user_id": 12345,
        "full_name": "John Smith",
        "username": "jsmith",
        "id_number": "8001015001081",
        "email": "john.smith@example.com",
        "vehicle_registration": "ABC123GP",
        "vehicle_make": "Toyota",
        "vehicle_model": "Corolla",
        "vehicle_color": "Silver",
        "outstanding_amount": "R1250.00",
        "subscription_amount": "R250.00",
        "subscription_date": "25th of each month",
        "account_status": "Overdue",
        "cancellation_fee": "R2500.00",
        "total_balance": "R3750.00"
    }
    
    # Configuration for agent
    config = {
        "llm": llm,
        "client_details": client_details,
        "script_type": "ratio_1_inflow",
        "verification": {
            "max_name_verification_attempts": 3,
            "max_details_verification_attempts": 3
        },
        "debug_mode": True,
        "show_logs": True
    }
    
    # Create and return agent
    return CallCenterAgent(config)

def run_interactive_demo():
    """Run an interactive demo with the agent."""
    print("\n=== Call Center Agent Demo ===")
    print("Type 'exit' or 'quit' to end the conversation.")
    print("Agent will simulate a debt collection call for Cartrack.\n")
    
    # Create agent
    agent = create_demo_agent()
    
    # Start conversation
    print("Agent: Hello! This is Cartrack's accounts department. Can I speak with John Smith?")
    
    while True:
        # Get user input
        user_input = input("\nYou: ")
        
        # Check for exit command
        if user_input.lower() in ["exit", "quit"]:
            print("\nDemo ended.")
            break
            
        # Get agent response
        response = agent.run(user_input)
        print(f"\nAgent: {response}")

if __name__ == "__main__":
    run_interactive_demo()

# %% [markdown]
# ### Test Router

# %%
import json
import os
import sys
import time # Import the time module
import traceback # For detailed error printing
import pprint # For printing complex objects if JSON fails
from typing import List, Dict, Any, Optional

# Attempt to import your actual application config and agent components
try:
    # Assuming app_config.py is in a location accessible via PYTHONPATH
    from app_config import CONFIG
except ImportError:
    print("Warning: Could not import app_config. Using default mock config.")
    CONFIG = {"client_details": {"full_name": "Test Client"}} # Fallback config

try:
    # Assuming src/Agents/agent00_debtor_call_center.py is accessible
    from src.Agents.agent00_debtor_call_center import (
        CallCenterAgent,
        CallCenterAgentState,
        CallStep,
        VerificationStatus,
        PaymentMethod
    )
    # Import message types from langchain core
    from langchain_core.messages import HumanMessage, AIMessage, SystemMessage, BaseMessage
except ImportError as e:
    print(f"FATAL ERROR: Could not import required Agent components: {e}")
    print("Please ensure the script is run from a location where 'app_config' and 'src' are accessible.")
    sys.exit(1) # Exit if essential components are missing


# Global agent initialization (Using Actual Agent)
# Ensure CONFIG is loaded correctly before this point
try:
    agent_config = CONFIG.copy()
    # Add any necessary default values or overrides for testing if needed
    # e.g., agent_config['llm'] = get_mock_llm_if_needed_for_testing()
    AGENT = CallCenterAgent(agent_config)
    AGENT.show_logs = True  # Enable logging to see more details
    print("Successfully initialized CallCenterAgent.")
except Exception as e:
    print(f"FATAL ERROR: Failed to initialize CallCenterAgent: {e}")
    traceback.print_exc()
    sys.exit(1)


def capture_output(func):
    """
    Decorator to capture stdout and stderr

    Returns:
        Tuple of (original return value, captured stdout, captured stderr)
    """
    def wrapper(*args, **kwargs):
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        import io
        stdout_capture = io.StringIO()
        stderr_capture = io.StringIO()
        try:
            sys.stdout = stdout_capture
            sys.stderr = stderr_capture
            result = func(*args, **kwargs)
            stdout_output = stdout_capture.getvalue()
            stderr_output = stderr_capture.getvalue()
            return result, stdout_output, stderr_output
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr
    return wrapper

def safe_serialize(obj, processed_ids=None):
    """
    Convert non-serializable objects to string representation, handling potential cycles.
    """
    if processed_ids is None:
        processed_ids = set()

    # Prevent infinite recursion on complex objects
    obj_id = id(obj)
    if obj_id in processed_ids:
        return "<Cycle Detected>"
    processed_ids.add(obj_id)

    try:
        if isinstance(obj, (HumanMessage, AIMessage, SystemMessage, BaseMessage)):
             # Use a standard representation for Langchain messages
             return f"[{obj.__class__.__name__} type='{getattr(obj, 'type', 'N/A')}'] {getattr(obj, 'content', '<No Content>')}"
        elif isinstance(obj, CallCenterAgentState):
             # Special handling for the state object if needed, accessing its internal dict
             # Accessing .dict() might be necessary if it's a Pydantic model or similar state manager
             if hasattr(obj, 'dict'):
                 state_dict = obj.dict()
             elif isinstance(obj, dict):
                 state_dict = obj
             else:
                 # Fallback if it's neither dict nor has .dict()
                 state_dict = obj.__dict__ if hasattr(obj, '__dict__') else {}

             # Serialize the state dictionary, excluding messages to avoid large output/recursion
             return {k: safe_serialize(v, processed_ids.copy()) for k, v in state_dict.items() if k != 'messages' and not k.startswith('_')}
        elif hasattr(obj, '__dict__'):
             # Generic handling for other objects
             return {k: safe_serialize(v, processed_ids.copy()) for k, v in obj.__dict__.items() if not k.startswith('_')}
        elif isinstance(obj, (list, tuple)):
            return [safe_serialize(item, processed_ids.copy()) for item in obj]
        elif isinstance(obj, dict):
            return {k: safe_serialize(v, processed_ids.copy()) for k, v in obj.items()}

        # Attempt standard JSON serialization if object is simple enough
        json.dumps(obj)
        result = obj
    except (TypeError, OverflowError):
        # Fallback to string representation for complex/unserializable types
        try:
            result = repr(obj)
        except Exception:
            result = "<Unserializable Object>"
    finally:
        processed_ids.remove(obj_id) # Backtrack after processing

    return result


def pretty_print(title: str, data: Any) -> None:
    """Pretty print test scenario details with safe serialization"""
    print(f"\n{'='*50}")
    print(f"{title}")
    print(f"{'='*50}")
    try:
        safe_data = safe_serialize(data)
        print(json.dumps(safe_data, indent=2, default=str)) # Use default=str for any lingering issues
    except Exception as e:
        print(f"Serialization Error during JSON dump: {e}. Falling back to pprint.")
        pprint.pprint(data) # Fallback to pprint for better complex object display
    print(f"{'='*50}")


def create_test_state(
    messages: List[BaseMessage],
    current_step: Optional[str] = None,
    verification_status: Optional[str] = None,
    additional_context: Optional[Dict[str, Any]] = None
) -> CallCenterAgentState:
    """
    Enhanced helper function to create a test state using the actual CallCenterAgentState.
    """
    # Prepare the initial state dictionary
    initial_state_dict = {"messages": messages}

    if current_step:
        initial_state_dict['current_call_step'] = current_step
    if verification_status:
        initial_state_dict['name_verification_status'] = verification_status # Or appropriate field
    if additional_context:
        initial_state_dict.update(additional_context)

    # Instantiate the actual CallCenterAgentState
    # This assumes CallCenterAgentState can be initialized from a dictionary
    # or has fields that can be set. Adjust if initialization is different.
    try:
        # If CallCenterAgentState inherits from LangGraph's MessagesState or similar Pydantic models:
        state = CallCenterAgentState(**initial_state_dict)
        # OR if it's a simpler class:
        # state = CallCenterAgentState()
        # for key, value in initial_state_dict.items():
        #     if hasattr(state, key):
        #         setattr(state, key, value)
        #     else:
        #         # Handle cases where state object might store things differently (e.g., in a dict attribute)
        #         # This depends heavily on CallCenterAgentState's implementation
        #         pass # Add specific logic if needed based on your state class design
    except Exception as e:
        print(f"Error creating CallCenterAgentState: {e}. Using raw dict as fallback.")
        # Fallback to using a dictionary if state class instantiation fails
        state = initial_state_dict

    return state

@capture_output
def test_scenario(
    scenario_name: str,
    messages: List[BaseMessage],
    current_step: Optional[str] = None,
    verification_status: Optional[str] = None,
    additional_context: Optional[Dict[str, Any]] = None,
    expected: Optional[Dict[str, Any]] = None
) -> Dict[str, Any]:
    """Generic test scenario runner with performance timing"""
    print(f"\n{'='*50}")
    print(f"TEST SCENARIO: {scenario_name}")
    print(f"{'='*50}")

    # Prepare state using the actual State class
    state = create_test_state(
        messages=messages,
        current_step=current_step,
        verification_status=verification_status,
        additional_context=additional_context
    )

    # Print input context
    print("\n--- Input Context ---")
    print("Conversation:")
    for msg in messages:
        # Use the updated safe_serialize which handles actual message objects
        print(safe_serialize(msg))

    print("\n--- State Before Router ---")
    # Use safe_serialize for potentially complex state object
    pretty_print("Initial State", state)


    # --- PERFORMANCE TIMING START ---
    start_time = time.perf_counter()
    # ---

    # Run router
    updates = {} # Initialize updates
    duration_ms = 0.0
    try:
        # Ensure the state object passed is compatible with what AGENT._router expects
        # If _router expects a dictionary, you might need to convert `state` back or adjust _router
        # Assuming _router can handle the CallCenterAgentState object directly:
        updates = AGENT._router(state) # Call the agent's router function

        # --- PERFORMANCE TIMING END ---
        end_time = time.perf_counter()
        duration_ms = (end_time - start_time) * 1000
        # ---

        # Print router results
        print("\n--- Router Analysis ---")
        pretty_print("Router Updates", updates)

        # --- PRINT PERFORMANCE ---
        print("\n--- Performance ---")
        print(f"Router Execution Time: {duration_ms:.2f} ms")
        # ---

        # Verify key outputs
        print("\n--- Verification ---")
        # Adapt keys based on your actual router's output structure
        print(f"Recommended Next Node: {updates.get('recommended_next_node', 'N/A')}")
        print(f"Router Reasoning: {updates.get('router_reasoning', 'N/A')}")


        print("\n✓ Router processing completed successfully")

        # Optional validation
        if expected:
            print("\n--- Expectation Validation ---")
            scenario_passed = True
            for key, expected_value in expected.items():
                actual_value = updates.get(key)
                print(f"{key}: Expected='{expected_value}', Got='{actual_value}'")

                # Compare values
                if actual_value != expected_value:
                    print(f"❌ FAILED: Mismatch in {key}")
                    scenario_passed = False
                else:
                    print(f"✅ PASSED: {key}")

            print(f"\nScenario '{scenario_name}': {'PASSED ✓' if scenario_passed else 'FAILED ✗'}")

    except Exception as e:
        # --- PERFORMANCE TIMING END (on error) ---
        end_time = time.perf_counter()
        duration_ms = (end_time - start_time) * 1000
        # ---
        print(f"\n--- Performance (Error) ---")
        print(f"Time until error: {duration_ms:.2f} ms")
        print(f"\n❌ Error in router processing: {e}")
        traceback.print_exc() # Print full traceback for debugging
        updates = {"error": str(e), "duration_ms": duration_ms} # Include duration in error case

    # Add duration to the returned results for potential aggregation
    updates['duration_ms'] = duration_ms
    return updates

def generate_test_scenarios():
    """Generate comprehensive test scenarios using actual message types"""
    # Use the actual HumanMessage and AIMessage classes imported
    return [
         # --- Verification Scenarios ---
        {
            "name": "Name Verification - Verified",
             "messages": [
                 AIMessage(content="Good day, this is Cartrack. May I speak to Test Client?"),
                 HumanMessage(content="Yes, speaking.")
             ],
             "current_step": CallStep.INTRODUCTION.value,
             "verification_status": VerificationStatus.INSUFFICIENT_INFO.value,
             "expected": {
                 "recommended_next_node": "name_verification_tool" # Expect router to go to name tool first
             }
         },
        {
            "name": "Details Verification - Sufficient Info Provided",
            "messages": [
                AIMessage(content="Thanks, Can you confirm your vehicle registration?"),
                HumanMessage(content="Yes, it's AB12CD GP")
            ],
            "current_step": CallStep.DETAILS_VERIFICATION.value,
            "verification_status": VerificationStatus.VERIFIED.value, # Assume name verified
            "additional_context": {
                "details_verification_status": VerificationStatus.VERIFIED.value
            },
            "expected": {
                # Router should decide based on verified details state
                "recommended_next_node": "reason_for_call" # Or whatever your router logic dictates
            }
        },
        {
            "name": "Details Verification - Insufficient/Incorrect Info",
            "messages": [
                AIMessage(content="Okay, and what is your email address on file?"),
                HumanMessage(content="I think it's john.doe@example.com")
            ],
            "current_step": CallStep.DETAILS_VERIFICATION.value,
            "verification_status": VerificationStatus.VERIFIED.value, # Name verified
             "additional_context": {
                 "details_verification_status": VerificationStatus.INSUFFICIENT_INFO.value
             },
             "expected": {
                 "recommended_next_node": "details_verification_tool" # Expect router to retry details
             }
        },

         # --- Post-Verification Flow ---
        {
            "name": "Transition from Reason For Call",
            "messages": [
                AIMessage(content="...and an immediate payment of R500 is required."),
                HumanMessage(content="Okay, I understand.")
            ],
            "current_step": CallStep.REASON_FOR_CALL.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                "recommended_next_node": "negotiation"
            }
        },
        {
            "name": "Negotiation - Acknowledging Consequences",
            "messages": [
                AIMessage(content="Failure to pay means services like the app will be suspended."),
                HumanMessage(content="Oh, I didn't realize that would happen.")
            ],
            "current_step": CallStep.NEGOTIATION.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 # Expect router to continue negotiation or move based on sentiment/rules
                 "recommended_next_node": "negotiation" # Or "promise_to_pay" depending on router logic
             }
        },
         {
            "name": "Negotiation - Agreeing to Discount Offer (Pre-Legal)",
            "messages": [
                AIMessage(content="We can offer a 50% discount if paid this month. Can you take this offer?"),
                HumanMessage(content="Yes, that sounds good, I can do that.")
            ],
            "current_step": CallStep.NEGOTIATION.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 "recommended_next_node": "promise_to_pay" # Router detects payment intent
             }
        },
        {
            "name": "PromiseToPay - Client Chooses DebiCheck",
            "messages": [
                AIMessage(content="How would you like to arrange the payment? We have DebiCheck, Portal link, or immediate debit."),
                HumanMessage(content="Let's do the DebiCheck option.")
            ],
            "current_step": CallStep.PROMISE_TO_PAY.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 # Router detects payment intent, might stay in PTP or move based on rules
                 "recommended_next_node": "promise_to_pay" # Or "debicheck_setup" depending on exact rules
             }
        },
         {
            "name": "PromiseToPay - Client Chooses Payment Portal",
            "messages": [
                AIMessage(content="How would you like to arrange the payment? We have DebiCheck, Portal link, or immediate debit."),
                HumanMessage(content="Send me the link for the payment portal.")
            ],
            "current_step": CallStep.PROMISE_TO_PAY.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 # Router detects payment intent/request
                 "recommended_next_node": "promise_to_pay" # Or "payment_portal" depending on rules
             }
        },
        {
            "name": "After DebiCheck Setup Explanation",
            "messages": [
                AIMessage(content="...so please approve the request from your bank app."),
                HumanMessage(content="Okay, I will look out for it.")
            ],
            "current_step": CallStep.DEBICHECK_SETUP.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 "recommended_next_node": "subscription_reminder"
             }
        },
        {
            "name": "After Payment Portal Guidance",
            "messages": [
                AIMessage(content="...you can click the link and follow the steps to pay online."),
                HumanMessage(content="Got it, thanks.")
            ],
            "current_step": CallStep.PAYMENT_PORTAL.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 "recommended_next_node": "subscription_reminder"
             }
        },
          {
            "name": "After Subscription Reminder",
            "messages": [
                AIMessage(content="Just confirming your normal subscription will also debit on the usual date."),
                HumanMessage(content="Alright.")
            ],
            "current_step": CallStep.SUBSCRIPTION_REMINDER.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 "recommended_next_node": "client_details_update"
             }
        },
        {
            "name": "After Client Details Update",
            "messages": [
                AIMessage(content="Thanks, I've updated your email address."),
                HumanMessage(content="Okay, great.")
            ],
            "current_step": CallStep.CLIENT_DETAILS_UPDATE.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 "recommended_next_node": "referrals"
             }
        },
        {
            "name": "After Referrals (Declined)",
            "messages": [
                AIMessage(content="Do you know anyone who might be interested in Cartrack?"),
                HumanMessage(content="No, not really.")
            ],
            "current_step": CallStep.REFERRALS.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 "recommended_next_node": "further_assistance"
             }
        },
          {
            "name": "After Further Assistance (No more questions)",
            "messages": [
                AIMessage(content="Is there anything else I can help with today?"),
                HumanMessage(content="No, that's all, thank you.")
            ],
            "current_step": CallStep.FURTHER_ASSISTANCE.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 "recommended_next_node": "closing"
             }
        },
          # --- Query during Negotiation ---
        {
            "name": "Query about Discount Terms during Negotiation",
            "messages": [
                AIMessage(content="We are offering a discount..."),
                HumanMessage(content="How long is that discount valid for?")
            ],
            "current_step": CallStep.NEGOTIATION.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 "recommended_next_node": "query_handler" # Router detects query
             }
        },
        # --- Request Cancellation ---
        {
            "name": "Request Cancellation during Negotiation",
            "messages": [
                AIMessage(content="Paying now reinstates your services."),
                HumanMessage(content="Actually, I just want to cancel my service.")
            ],
            "current_step": CallStep.NEGOTIATION.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                "recommended_next_node": "cancellation" # Router detects cancellation request
            }
        },
        # --- Edge Case: Empty/Garbage Input ---
        {
            "name": "Empty Client Message after Verification",
            "messages": [
                AIMessage(content="Okay, your details are verified. The reason for the call is..."),
                HumanMessage(content="") # Empty message
            ],
            "current_step": CallStep.REASON_FOR_CALL.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 "recommended_next_node": "negotiation" # Router applies standard progression
             }
        },
        {
            "name": "Unrelated Statement during Negotiation",
            "messages": [
                AIMessage(content="Paying now reinstates your services."),
                HumanMessage(content="The weather is nice today.")
            ],
            "current_step": CallStep.NEGOTIATION.value,
            "verification_status": VerificationStatus.VERIFIED.value,
            "expected": {
                 # Router should apply standard progression or re-engage based on its rules
                 "recommended_next_node": "negotiation" # Example: try to re-engage
             }
        },

    ]

def run_comprehensive_tests():
    """Run comprehensive router tests and collect performance data"""
    print("\n=== Running Comprehensive Router Tests ===")

    scenarios = generate_test_scenarios()
    results_summary = []
    total_duration = 0
    test_count = 0

    for i, scenario in enumerate(scenarios):
        print(f"\n--- Starting Scenario {i+1}: {scenario['name']} ---")
        # Prepare scenario details
        test_params = {
            "scenario_name": scenario["name"],
            "messages": scenario.get("messages", []),
            "current_step": scenario.get("current_step"),
            "verification_status": scenario.get("verification_status"),
            "additional_context": scenario.get("additional_context"),
            "expected": scenario.get("expected")
        }

        # Run test scenario with output capture
        result, stdout, stderr = test_scenario(**test_params)

        # Store result summary
        duration = result.get('duration_ms', 0)
        scenario_passed = result.get('error') is None and (
            not scenario.get("expected") or
            result.get("recommended_next_node") == scenario["expected"].get("recommended_next_node")
        )

        results_summary.append({
            "scenario": scenario["name"],
            "recommended_node": result.get("recommended_next_node", "ERROR"),
            "reasoning": result.get("router_reasoning", "N/A"),
            "duration_ms": duration,
            "passed_validation": scenario_passed,
            "error": result.get("error")
        })

        if result.get('error') is None:
            total_duration += duration
            test_count += 1
        else:
             print(f"ERROR recorded for scenario: {result.get('error')}")


        # Print captured stdout/stderr if needed for debugging LLM calls within router
        # if stdout:
        #      print(f"\n--- Captured STDOUT for Scenario {i+1} ---")
        #      print(stdout)
        # if stderr:
        #      print(f"\n--- Captured STDERR for Scenario {i+1} ---")
        #      print(stderr)
        print(f"\n{'='*20} End Scenario {i+1} {'='*20}\n")


    print("\n=== Router Test Summary ===")
    passed_count = sum(1 for r in results_summary if r['passed_validation'])
    failed_count = len(results_summary) - passed_count

    print(f"Total Scenarios: {len(results_summary)}")
    print(f"Passed: {passed_count}")
    print(f"Failed: {failed_count}")

    if test_count > 0:
        average_duration = total_duration / test_count
        print(f"\nAverage Router Execution Time (Successful Runs): {average_duration:.2f} ms")
    else:
        print("\nNo successful runs to calculate average time.")

    # Optionally print detailed results
    print("\n--- Detailed Results ---")
    for res in results_summary:
         status = "✅ PASSED" if res['passed_validation'] else "❌ FAILED"
         print(f"[{status}] Scenario: {res['scenario']}")
         print(f"  -> Recommended Node: {res['recommended_node']}")
         print(f"  -> Reasoning: {res['reasoning']}")
         print(f"  -> Duration: {res['duration_ms']:.2f} ms")
         if res['error']:
             print(f"  -> Error: {res['error']}")


    print("\n=== All Comprehensive Router Tests Completed ===")

if __name__ == "__main__":
    # Basic check to ensure AGENT is initialized before running tests
    if 'AGENT' in locals() and AGENT is not None:
        run_comprehensive_tests()
    else:
        print("Agent initialization failed. Cannot run tests.")
